# %%
import os
import json
import functools
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv(r"D:\shalini\HS_DataClean_Nov.csv")

# %%
# Step 1: Read the config.json file
with open("D:\Healthscore Codes\healthscore_dashboard_old2.json", 'r') as file:
    config_data = json.load(file)

# Step 2: Extract config1 and config2 from the file
display_name_mapping = config_data['display_name_mapping']
metric_nature_mapping = config_data['metric_nature_mapping']
level_1_metrics = config_data['level_1_metrics']
level_2_metrics = config_data['level_2_metrics']
level_3_metrics = config_data['level_3_metrics']
level_4_metrics = config_data['level_4_metrics']
level_5_metrics = config_data['level_5_metrics']
feature_groups = config_data['feature_groups']
feature_seqno_mapping = config_data['feature_seqno_mapping']
metric_seqnum_mapping = config_data['metric_seqnum_mapping']


# Step 3: Verify the contents
print(display_name_mapping)
print(metric_nature_mapping)
print(level_1_metrics)
print(level_2_metrics)
print(level_3_metrics)
print(level_4_metrics)
print(level_5_metrics)
print(feature_groups)
print(feature_seqno_mapping)
print(metric_seqnum_mapping)
# Out:
# {'DR_Visits': 'Visits', 'Unique Visitors': 'Visitors', 'Page Views': 'Page Views', 'Average Time Spent on Page': 'Average Time Spent (mins)', 'DR_New Visitors': 'New Visitors', 'DR_Server Errors': 'Server Errors', 'DR_Overall Chat': 'Visits to Chat', 'DR_continuing chat from new chat page': 'Continuing chat from new chat page', 'DR_Message Us': 'Visits to Chat (Bot)', 'DR_Agent Chat': 'Visits to Agent Chat (Skip bot)', 'DR_Self Service Initiated': 'Visits to Self Service Features', 'DR_CoxApp | Visits with Chat and No Self Service Initiated': 'Visits with Chat but No Self Service', 'DR_CoxApp | Visits with No Self Service and No Chat': 'Visits with Neither Self Service nor Chat', 'DR_CoxApp | Visits not logged in': 'Not Logged-in Visits', 'DR_Login Page Visits': 'Login Page Visits', 'DR_Successful logins': 'Login Success Rate', 'DR_Auto Logins': 'Share of Auto Login (Remember/Biometrics)', 'DR_Clicks to MFA Verification': 'with TSV', 'DR_Clicks on Forgot User ID': 'User ID Recovery', 'Clicks on Forgot Password': 'Password Reset', 'DR_Need to Register': 'Registration', 'DR_Visits to Billing Home': 'Billing Section Visits', 'DR_Billing Make a Payment': 'Make Payments', 'DR_Payment Submit': 'Payment Submit', 'DR_Payments': 'Payment Success Rate', 'DR_Client Errors on Make Payment': 'Client Errors on Payment Page', 'DR_Server Errors on Make Payment': 'Server Errors on Payment Page', 'DR_Promise to Pay': 'Promise to Pay - Linkout', 'DR_Promise to Pay (Native)': 'Promise to Pay - Native', 'DR_CoxApp | Billing - Additional time to pay (Link out)': 'Additional time to pay - Linkout', 'DR_CoxApp | Billing - Future date payment (Link out)': 'Future date payment - Linkout', 'DR_Billing - View Bill Details': 'Bill Downloads', 'DR_Billing - Activity & Statements': 'Activity & Statements', 'DR_Billing - Automatic Payments': 'Easy Pay Enrollments', 'DR_Billing - Manage Payment Methods': 'Payment Method Changes', 'DR_Billing - Agreements & Discounts': 'Agreement & Discounts', 'DR_Billing - Bill Delivery': 'Bill Delivery Options', 'DR_Billing - Edit Billing Address': 'Address Changes', 'DR_Billing - Move My Service': 'Move Service', 'DR_Billing visits to chat': 'Billing_Interacted with chat', 'DR_Visits where One EC Card was shown': 'Easy Connect Eligible Visits', 'DR_EC Flow>Success': 'Overall Success', 'DR_EC>Failure': 'Overall Failure', 'DR_EC Flow>Timeout': 'Overall Timeout', 'DR_EC>No Result': 'Overall No Result', 'DR_Easy Connect - Started': 'Started the Flow', 'DR_Easy Connect Started - Success': 'Success', 'DR_Easy Connect Started - Failure': 'Failure', 'DR_Easy Connect Started - Timeout': 'Timeout', 'DR_Easy Connect Started - No Result': 'No Result', 'DR_Visits who did not Start EC Flow': 'Did Not Start the Flow', 'DR_Visits who did not Start EC Flow - Success': 'Did_not Success', 'DR_Visits who did not Start EC Flow - Failure': 'Did_not Failure', 'DR_Visits who did not Start EC Flow - No Result': 'Did_not No Result', 'DR_Easy Connect - Started Agent Chat': 'Easyconnect_Interacted with Chat', 'DR_SmartHelp - Landing Page': 'Devices Page Visits', 'DR_SmartHelp - Started': 'Started Troubleshooting (Solution Center)', 'DR_SmartHelp - Result': 'Saw a Result', 'DR_SmartHelp Result - Unknown': '1st common reason (Unknown)', 'DR_SmartHelp Result - Disconnected': '2nd common reason (Disconnected)', 'DR_SmartHelp Result - Incomplete Install': '3rd common reason (Incomplete Install)', 'DR_SmartHelp - Reboot Flow Started': 'Did a Device Reboot', 'DR_SmartHelp - P&P': 'Started Proactive and Preventive (P&P)', "DR_Smarthelp P&P - Let's troubleshoot together": 'Started P&P troubleshooting', 'DR_Smarthelp P&P - Reset Complete': 'Smarthelp Reset Complete', "DR_Smarthelp P&P - Let's schedule a technician visit": 'Schedule Tech', 'DR_Smarthelp P&P - Connect with a support agent': 'Connect with Agent', 'DR_Smarthelp P&P - Interacted with Chat Agent': 'Smarthelp_P&P Interacted with Chat', 'DR_SmartHelp - Billing & Account Support': 'Clicked Billing & Acc ...
# {'Visits': 'Positive', 'Visitors': 'Positive', 'Page Views': 'Positive', 'Average Time Spent (mins)': 'Negative', 'New Visitors': 'Positive', 'Server Errors': 'Negative', 'Visits to Chat': 'Negative', 'Visits to Chat (Bot)': 'Negative', 'Visits to Agent Chat (Skip bot)': 'Negative', 'Visits to Self Service Features': 'Positive', 'Visits with Chat but No Self Service': 'Negative', 'Visits with Neither Self Service nor Chat': 'Negative', 'Not Logged-in Visits': 'Negative', 'Login Page Visits': 'Positive', 'Login Success Rate': 'Positive', 'Share of Auto Login (Remember/Biometrics)': 'Positive', 'with TSV': 'Positive', 'User ID Recovery': 'Negative', 'Password Reset': 'Negative', 'Registration': 'Positive', 'Billing Section Visits': 'Positive', 'Make Payments': 'Positive', 'Payment Submit': 'Positive', 'Payment Success Rate': 'Positive', 'Client Errors on Payment Page': 'Negative', 'Server Errors on Payment Page': 'Negative', 'Promise to Pay - Linkout': 'Positive', 'Promise to Pay - Native': 'Positive', 'Additional time to pay - Linkout': 'Positive', 'Future date payment - Linkout': 'Positive', 'Bill Downloads': 'Positive', 'Activity & Statements': 'Positive', 'Easy Pay Enrollments': 'Positive', 'Payment Method Changes': 'Positive', 'Agreement & Discounts': 'Positive', 'Bill Delivery Options': 'Positive', 'Address Changes': 'Positive', 'Move Service': 'Positive', 'Billing_Interacted with chat': 'Negative', 'Easy Connect Eligible Visits': 'Positive', 'Overall Success': 'Positive', 'Overall Failure': 'Negative', 'Overall Timeout': 'Negative', 'Overall No Result': 'Negative', 'Started the Flow': 'Positive', 'Success': 'Positive', 'Failure': 'Negative', 'Timeout': 'Negative', 'No Result': 'Negative', 'Easyconnect_Interacted with Chat': 'Negative', 'Did Not Start the Flow': 'Negative', 'Did_not Success': 'Positive', 'Did_not Failure': 'Negative', 'Did_not No Result': 'Negative', 'Devices Page Visits': 'Positive', 'Started Troubleshooting (Solution Center)': 'Positive', 'Saw a Result': 'Positive', '1st common reason (Unknown)': 'Negative', '2nd common reason (Disconnected)': 'Negative', '3rd common reason (Incomplete Install)': 'Negative', 'Did a Device Reboot': 'Positive', 'Started Proactive and Preventive (P&P)': 'Positive', 'Started P&P troubleshooting': 'Positive', 'Smarthelp Reset Complete': 'Positive', 'Schedule Tech': 'Positive', 'Connect with Agent': 'Negative', 'Smarthelp_P&P Interacted with Chat': 'Negative', 'Clicked Billing & Account Support': 'Positive', 'Clicked Internet Support': 'Positive', 'Clicked TV Support': 'Positive', 'Clicked Homelife Support': 'Positive', 'Smarthelp_Interacted with Chat': 'Negative', 'Reset Modem Start Page Visits': 'Positive', 'Started Reset Process': 'Positive', 'Reset Process Complete': 'Positive', 'Reset Process Incomplete': 'Negative', 'Reset_Modem Interacted with Chat': 'Negative', 'Error Outage': 'Negative', 'Non Pay Error': 'Negative', 'DMCA Error': 'Negative', 'Reset TV Box Start Page Visits': 'Positive', 'Reset_TV Started Reset Process': 'Positive', 'Reset_TV Process Complete': 'Positive', 'Reset_TV Process Incomplete': 'Negative', 'Reset_TV Interacted with Chat': 'Negative', 'Reset_TV Error Outage': 'Negative', 'Reset_TV Non Pay Error': 'Negative', 'Reset_TV DMCA Error': 'Negative', 'Total Visits from web ecomm': 'Positive', 'Total Orders from web ecomm': 'Positive', 'Visits sent from app to cox.com': 'Positive', 'Orders generated': 'Positive', 'Data Usage': 'Positive', 'Plan Changes': 'Positive', 'CRO': 'Positive', 'Transfer': 'Positive', 'Visits to Registration Home Page': 'Positive', 'New Registrations': 'Positive', 'Already Registered': 'Positive', 'Did not Register': 'Negative', 'Intent to Register': 'Positive', 'Funnel Success Rate': 'Positive', 'Phone Lookup': 'Positive', 'Phone Lookup Success Rate': 'Positive', 'Email Lookup': 'Positive', 'Email Lookup Success Rate': 'Positive', 'Reg_native Server Errors': 'Negative', 'Reg_native Interacted with Chat': 'Negative', 'Total Data  ...
# ['Visits', 'Login Page Visits', 'Billing Section Visits', 'Easy Connect Eligible Visits', 'Devices Page Visits', 'Reset Modem Start Page Visits', 'Reset TV Box Start Page Visits', 'Visits sent from app to cox.com', 'Visits to Registration Home Page', 'Intent to Register', 'Phone Lookup', 'Email Lookup', 'Total Data Usage Visits', 'Support Home Visits', 'Visits to TSV Home Page', 'TSV Phone Text', 'TSV Phone Call', 'TSV Email Text', "Visits from 'Cox Mobile' users", 'Visits with Service Alert', 'Notifi_center Visits with Bell icon']
# ['New Visitors', 'Server Errors', 'Visits to Chat', 'Visits to Chat (Bot)', 'Visits to Agent Chat (Skip bot)', 'Visits to Self Service Features', 'Visits with Chat but No Self Service', 'Visits with Neither Self Service nor Chat', 'Not Logged-in Visits', 'Login Success Rate', 'with TSV', 'User ID Recovery', 'Password Reset', 'Registration', 'Make Payments', 'Payment Submit', 'Promise to Pay - Linkout', 'Promise to Pay - Native', 'Bill Downloads', 'Activity & Statements', 'Easy Pay Enrollments', 'Payment Method Changes', 'Agreement & Discounts', 'Bill Delivery Options', 'Address Changes', 'Move Service', 'Billing_Interacted with chat', 'Overall Success', 'Overall Failure', 'Overall Timeout', 'Overall No Result', 'Started the Flow', 'Did Not Start the Flow', 'Clicked Billing & Account Support', 'Clicked Internet Support', 'Clicked TV Support', 'Clicked Homelife Support', 'Did a Device Reboot', 'Smarthelp_Interacted with Chat', 'Started Troubleshooting (Solution Center)', 'Started Proactive and Preventive (P&P)', 'Started Reset Process', 'Error Outage', 'Non Pay Error', 'DMCA Error', 'Reset_TV Started Reset Process', 'Reset_TV Error Outage', 'Reset_TV Non Pay Error', 'Reset_TV DMCA Error', 'Data Usage', 'Plan Changes', 'CRO', 'Transfer', 'New Registrations', 'Already Registered', 'Did not Register', 'Reg_native Server Errors', 'Reg_native Interacted with Chat', 'Funnel Success Rate', 'Phone Lookup Success Rate', 'Email Lookup Success Rate', 'Data Plan Upgrade', 'Learn More', 'Courtesy Credit', 'Data usage >=75%', 'Data usage >=100%', 'Data_usage Interacted with Chat', 'Support Internet Support', 'Billing & Account Support', 'Billing Support', 'Account Support', 'Support TV Support', 'Support Homelife Support', 'Support Mobile Support', 'Read an Article', 'Support Search', 'Went to External Link', 'App Feedback', 'Support Interacted with Chat', 'TSV Enrollment Page', 'TSV Overall Success Rate', 'TSV Update', 'TSV Server Errors', 'TSV Text Success Rate', 'TSV Call Success Rate', 'TSV Email Success Rate', 'Coxmob Line Detail Page', 'Coxmob Gig Unlimited Plan', 'Coxmob Billing Home', 'Coxmob Make Additional Payment', 'Coxmob Payment Method Changes', 'Coxmob Activity & Statements', 'Coxmob Easypay Enrollment', 'Coxmob Bill Delivery Changes', 'Coxmob Support Section', 'Coxmob Pay as you Gig', 'Service_alert Outage', 'Service_alert Campaign Rolloff', 'Service_alert NonPay Suspension', 'Service_alert Network Construction', 'Service_alert DMCA Termination', 'Notifi_center Visits with new notifications', 'Notifi_center Visits with no new notifications']
# ['Share of Auto Login (Remember/Biometrics)', 'Client Errors on Payment Page', 'Server Errors on Payment Page', 'Payment Success Rate', 'Additional time to pay - Linkout', 'Future date payment - Linkout', 'Success', 'Failure', 'Timeout', 'No Result', 'Did_not Success', 'Did_not Failure', 'Did_not No Result', 'Easyconnect_Interacted with Chat', 'Saw a Result', 'Connect with Agent', 'Smarthelp_P&P Interacted with Chat', 'Schedule Tech', 'Started P&P troubleshooting', 'Smarthelp Reset Complete', 'Reset Process Complete', 'Reset Process Incomplete', 'Reset_Modem Interacted with Chat', 'Reset_TV Process Complete', 'Reset_TV Process Incomplete', 'Reset_TV Interacted with Chat', 'Coxmob Add a Line', 'Coxmob Change  Plan - linkout', 'Coxmob Change Plan - Native', 'Coxmob Welcome Guide', 'Coxmob Device Payment Plan', 'File a Claim', 'Coxmob Change Status External Link', 'Notifi_center Clicked bell with new notifications']
# ['1st common reason (Unknown)', '2nd common reason (Disconnected)', '3rd common reason (Incomplete Install)', 'Coxmob Account Restrictions', 'Coxmob Plan Purchased', 'Notifi_center Viewed', 'Notifi_center Declined', 'Notifi_center Accepted', 'Notifi_center No Action', 'with no new notifi Viewed', 'with no new notifi Declined', 'with no new notifi Accepted', 'with no new notifi No Action']
# ['Coxmob Gig Plan', 'Coxmob Unlimited Plan']
# {'OVER ALL': ['DR_Visits', 'Unique Visitors', 'Page Views', 'Average Time Spent on Page', 'DR_New Visitors', 'DR_Server Errors', 'DR_Overall Chat', 'DR_Message Us', 'DR_Agent Chat', 'DR_Self Service Initiated', 'DR_CoxApp | Visits with Chat and No Self Service Initiated', 'DR_CoxApp | Visits with No Self Service and No Chat', 'DR_CoxApp | Visits not logged in', 'DR_continuing chat from new chat page'], 'LOG IN': ['DR_Login Page Visits', 'DR_Successful logins', 'DR_Auto Logins', 'DR_Clicks to MFA Verification', 'DR_Clicks on Forgot User ID', 'Clicks on Forgot Password', 'DR_Need to Register'], 'BIL LING': ['DR_Visits to Billing Home', 'DR_Billing Make a Payment', 'DR_Payment Submit', 'DR_Payments', 'DR_Client Errors on Make Payment', 'DR_Server Errors on Make Payment', 'DR_Promise to Pay', 'DR_Promise to Pay (Native)', 'DR_CoxApp | Billing - Additional time to pay (Link out)', 'DR_CoxApp | Billing - Future date payment (Link out)', 'DR_Billing - View Bill Details', 'DR_Billing - Activity & Statements', 'DR_Billing - Automatic Payments', 'DR_Billing - Manage Payment Methods', 'DR_Billing - Agreements & Discounts', 'DR_Billing - Bill Delivery', 'DR_Billing - Edit Billing Address', 'DR_Billing - Move My Service', 'DR_Billing visits to chat'], 'EASY CON NECT': ['DR_Visits where One EC Card was shown', 'DR_EC Flow>Success', 'DR_EC>Failure', 'DR_EC Flow>Timeout', 'DR_EC>No Result', 'DR_Easy Connect - Started', 'DR_Easy Connect Started - Success', 'DR_Easy Connect Started - Failure', 'DR_Easy Connect Started - Timeout', 'DR_Easy Connect Started - No Result', 'DR_Easy Connect - Started Agent Chat', 'DR_Visits who did not Start EC Flow', 'DR_Visits who did not Start EC Flow - Success', 'DR_Visits who did not Start EC Flow - Failure', 'DR_Visits who did not Start EC Flow - No Result', 'DR_Easy Connect - Self install success', 'DR_Easy Connect - Self install success', 'DR_Easy Connect - Self install Timeout', 'DR_Easy Connect - Self install Timeout'], 'SMART HELP': ['DR_SmartHelp - Landing Page', 'DR_SmartHelp - Started', 'DR_SmartHelp - Result', 'DR_SmartHelp Result - Unknown', 'DR_SmartHelp Result - Disconnected', 'DR_SmartHelp Result - Incomplete Install', 'DR_SmartHelp - Reboot Flow Started', 'DR_SmartHelp - P&P', "DR_Smarthelp P&P - Let's troubleshoot together", 'DR_Smarthelp P&P - Reset Complete', "DR_Smarthelp P&P - Let's schedule a technician visit", 'DR_Smarthelp P&P - Connect with a support agent', 'DR_Smarthelp P&P - Interacted with Chat Agent', 'DR_SmartHelp - Billing & Account Support', 'DR_SmartHelp - Internet Support', 'DR_SmartHelp - TV Support', 'DR_SmartHelp - Homelife Support', 'DR_SmartHelp - Agent Chat'], 'RESET MODEM': ['DR_Reset Modem - Home Page', 'DR_Reset Modem - Started Rebooting Process', 'DR_Reset Modem - Rebooting Complete', 'DR_Reset Modem - Rebooting Incomplete', 'DR_Reset Modem - Agent Chat', 'DR_Reset Modem - Error Outage', 'DR_Reset Modem Error - Non Pay', 'DR_Reset Modem Error -DMCA'], 'RESET TV BOX': ['DR_Reset Tvbox - Home Page', 'DR_Reset Tvbox - Rebooting', 'DR_Reset Tvbox - Complete', 'DR_Reset Tvbox - Incomplete', 'DR_Reset Tvbox - Agent Chat', 'DR_Reset Tvbox - Error Outage', 'DR_Reset Tvbox Error - Non Pay', 'DR_Reset Tvbox Error - DMCA'], 'E COMMERCE': ['DR_Direct Ecomm Visits Traffic from to Cox.com', 'DR_Direct Ecomm order Traffic sent from cox.com', 'DR_Direct Ecomm Traffic sent from App to cox.com', 'DR_Direct Ecomm order Traffic sent from App to cox.com', 'DR_Data Plan Upgrade Ecomm Traffic sent from App to cox.com', 'DR_Service Plan Upgrade Ecomm Traffic sent from App to cox.com', 'DR_CRO Ecomm Traffic sent from App to cox.com', 'DR_Transfer Ecomm Traffic sent from App to cox.com'], 'RE GISTRATION (NATIVE)': ['DR_Native Registration Home Page', 'DR_Native Registration Confirmation', 'DR_Native Registration - Already Registered', 'DR_Native Registration - Did not Registered', 'DR_Native Registration - Intent to Register', 'DR_Native Registration Success', 'DR_Native Registration - Phone Lo ...
# {'BIL LING': '3', 'COX MOBILE': '13', 'DATA USAGE': '10', 'E COMMERCE': '8', 'EASY CON NECT': '4', 'KEY WORDS': '17', 'LOG IN': '2', 'NOTIFICATION CENTER': '15', 'OVER ALL': '1', 'RE GISTRATION (NATIVE)': '9', 'RESET MODEM': '6', 'RESET TV BOX': '7', 'S UPPORT': '11', 'SERVER ERRORS': '16', 'SERVICE ALERT': '14', 'SMART HELP': '5', 'TWO-STEP VERIFICATION': '12', 'U R L': '18'}
# {'Visits': '1', 'Visitors': '2', 'Page Views': '3', 'Average Time Spent (mins)': '4', 'New Visitors': '5', 'Server Errors': '6', 'Visits to Chat': '7', 'Visits to Chat (Bot)': '8', 'Visits to Agent Chat (Skip bot)': '9', 'Visits to Self Service Features': '10', 'Visits with Chat but No Self Service': '11', 'Visits with Neither Self Service nor Chat': '12', 'Not Logged-in Visits': '13', 'Login Page Visits': '1', 'Login Success Rate': '2', 'Share of Auto Login (Remember/Biometrics)': '3', 'with TSV': '4', 'User ID Recovery': '5', 'Password Reset': '6', 'Registration': '7', 'Billing Section Visits': '1', 'Make Payments': '2', 'Payment Submit': '3', 'Payment Success Rate': '4', 'Client Errors on Payment Page': '5', 'Server Errors on Payment Page': '6', 'Promise to Pay - Linkout': '7', 'Promise to Pay - Native': '8', 'Additional time to pay - Linkout': '9', 'Future date payment - Linkout': '10', 'Bill Downloads': '11', 'Activity & Statements': '12', 'Easy Pay Enrollments': '13', 'Payment Method Changes': '14', 'Agreement & Discounts': '15', 'Bill Delivery Options': '16', 'Address Changes': '17', 'Move Service': '18', 'Billing_Interacted with chat': '19', 'Easy Connect Eligible Visits': '1', 'Overall Success': '2', 'Overall Failure': '3', 'Overall Timeout': '4', 'Overall No Result': '5', 'Started the Flow': '6', 'Success': '7', 'Failure': '8', 'Timeout': '9', 'No Result': '10', 'Easyconnect_Interacted with Chat': '11', 'Did Not Start the Flow': '12', 'Did_not Success': '13', 'Did_not Failure': '14', 'Did_not No Result': '15', 'Devices Page Visits': '1', 'Started Troubleshooting (Solution Center)': '2', 'Saw a Result': '3', '1st common reason (Unknown)': '4', '2nd common reason (Disconnected)': '5', '3rd common reason (Incomplete Install)': '6', 'Did a Device Reboot': '7', 'Started Proactive and Preventive (P&P)': '8', 'Started P&P troubleshooting': '9', 'Smarthelp Reset Complete': '10', 'Schedule Tech': '11', 'Connect with Agent': '12', 'Smarthelp_P&P Interacted with Chat': '13', 'Clicked Billing & Account Support': '14', 'Clicked Internet Support': '15', 'Clicked TV Support': '16', 'Clicked Homelife Support': '17', 'Smarthelp_Interacted with Chat': '18', 'Reset Modem Start Page Visits': '1', 'Started Reset Process': '2', 'Reset Process Complete': '3', 'Reset Process Incomplete': '4', 'Reset_Modem Interacted with Chat': '5', 'Error Outage': '6', 'Non Pay Error': '7', 'DMCA Error': '8', 'Reset TV Box Start Page Visits': '1', 'Reset_TV Started Reset Process': '2', 'Reset_TV Process Complete': '3', 'Reset_TV Process Incomplete': '4', 'Reset_TV Interacted with Chat': '5', 'Reset_TV Error Outage': '6', 'Reset_TV Non Pay Error': '7', 'Reset_TV DMCA Error': '8', 'Total Visits from web ecomm': '1', 'Total Orders from web ecomm': '2', 'Visits sent from app to cox.com': '3', 'Orders generated': '4', 'Data Usage': '5', 'Plan Changes': '6', 'CRO': '7', 'Transfer': '8', 'Visits to Registration Home Page': '1', 'New Registrations': '2', 'Already Registered': '3', 'Did not Register': '4', 'Intent to Register': '5', 'Funnel Success Rate': '6', 'Phone Lookup': '7', 'Phone Lookup Success Rate': '8', 'Email Lookup': '9', 'Email Lookup Success Rate': '10', 'Reg_native Server Errors': '11', 'Reg_native Interacted with Chat': '12', 'Total Data Usage Visits': '1', 'Data Plan Upgrade': '2', 'Learn More': '3', 'Courtesy Credit': '4', 'Data usage >=75%': '5', 'Data usage >=100%': '6', 'Data_usage Interacted with Chat': '7', 'Support Home Visits': '1', 'Support Internet Support': '2', 'Billing & Account Support': '3', 'Billing Support': '4', 'Account Support': '5', 'Support TV Support': '6', 'Support Homelife Support': '7', 'Support Mobile Support': '8', 'Read an Article': '9', 'Support Search': '10', 'Went to External Link': '11', 'App Feedback': '12', 'Support Interacted with Chat': '13', 'Visits to TSV Home Page': '1', 'TSV Enrollment Page': '2', 'TSV Overall Success Rate': '3', 'TSV Phone Text': '4', 'TSV Text Success Rate': '5', 'TSV Phone Call': '6', 'T ...

# %%
df['display_names'] = df['Metrics'].map(display_name_mapping)

# %%
df['metric_nature'] = df['display_names'].map(metric_nature_mapping)

# %%
df['level_1'] = df['display_names'].apply(lambda x: x if x in level_1_metrics else None)
df['level_2'] = df['display_names'].apply(lambda x: x if x in level_2_metrics else None)
df['level_3'] = df['display_names'].apply(lambda x: x if x in level_3_metrics else None)
df['level_4'] = df['display_names'].apply(lambda x: x if x in level_4_metrics else None)
df['level_5'] = df['display_names'].apply(lambda x: x if x in level_5_metrics else None)

# %%
feature_column = 'Unknown'
df['Feature'] = feature_column
for group, metrics in feature_groups.items():
   df['Feature'] = np.where(df['Metrics'].isin(metrics), group, df['Feature'])

# %%
def move_row(df, from_idx, to_idx):
    row = df.iloc[from_idx]
    df = df.drop(from_idx).reset_index(drop=True)
    df = pd.concat([df.iloc[:to_idx], row.to_frame().T, df.iloc[to_idx:]]).reset_index(drop=True)
    return df

df = move_row(df, 50, 46)
df = move_row(df, 51, 47)
df = move_row(df, 52, 48)
df = move_row(df, 53, 49)
df = move_row(df, 164, 158)
df = move_row(df, 165, 159)
df = move_row(df, 180, 174)
df = move_row(df, 181, 175)
df = move_row(df, 218, 206)
df = move_row(df, 219, 207)
df = move_row(df, 220, 208)
df = move_row(df, 221, 209)
df = move_row(df, 280, 268)
df = move_row(df, 281, 269)
df = move_row(df, 282, 270)
df = move_row(df, 283, 271)

# %%
df['unique_identifier'] = df['Feature'].apply(lambda x: ''.join([word[0].upper() for word in x.split()]))

# %%
def generate_hierarchy_id_grouped_by_os(df):
    df['Hierarchy_ID'] = None

   
    df['Feature_Order'] = df.groupby('Operating System Type')['unique_identifier'].transform(lambda x: pd.Series(range(len(x)), index=x.index))

    grouped = df.groupby(['Operating System Type', 'unique_identifier'], group_keys=False)
    results = []

   
    for (os_name, unique_id), group in grouped:
        current_ids = {'level_1': 0, 'level_2': 0, 'level_3': 0, 'level_4': 0, 'level_5': 0}  

        group = group.sort_values('Feature_Order')  

        for index, row in group.iterrows():
            if pd.isna(row['display_names']):
                continue  

            if not pd.isna(row['level_1']):  
                current_ids['level_1'] += 1
                current_ids['level_2'] = 0  
                current_ids['level_3'] = 0  
                current_ids['level_4'] = 0  
                current_ids['level_5'] = 0  
                group.at[index, 'Hierarchy_ID'] = f"{os_name}_{unique_id}_{current_ids['level_1']}"

            elif not pd.isna(row['level_2']):  
                current_ids['level_2'] += 1
                current_ids['level_3'] = 0  
                current_ids['level_4'] = 0  
                current_ids['level_5'] = 0  
                group.at[index, 'Hierarchy_ID'] = f"{os_name}_{unique_id}_{current_ids['level_1']}.{current_ids['level_2']}"

            elif not pd.isna(row['level_3']):  
                current_ids['level_3'] += 1
                current_ids['level_4'] = 0  
                current_ids['level_5'] = 0  
                group.at[index, 'Hierarchy_ID'] = f"{os_name}_{unique_id}_{current_ids['level_1']}.{current_ids['level_2']}.{current_ids['level_3']}"

            elif not pd.isna(row['level_4']):  
                current_ids['level_4'] += 1
                current_ids['level_5'] = 0  
                group.at[index, 'Hierarchy_ID'] = f"{os_name}_{unique_id}_{current_ids['level_1']}.{current_ids['level_2']}.{current_ids['level_3']}.{current_ids['level_4']}"

            elif not pd.isna(row['level_5']):  
                current_ids['level_5'] += 1
                group.at[index, 'Hierarchy_ID'] = f"{os_name}_{unique_id}_{current_ids['level_1']}.{current_ids['level_2']}.{current_ids['level_3']}.{current_ids['level_4']}.{current_ids['level_5']}"

        results.append(group)

   
    df = pd.concat(results, ignore_index=True)

    
    #df = df[df['Display_Names'].notna()]

    
    cols = [col for col in df.columns if col != 'Hierarchy_ID' and col != 'Feature_Order'] + ['Hierarchy_ID']
    return df[cols]


df = generate_hierarchy_id_grouped_by_os(df)

# %%
df = generate_hierarchy_id_grouped_by_os(df)

def assign_parent_id(row):
    if not pd.isna(row['level_5']):  
        return f"{row['Hierarchy_ID'].rsplit('.', 1)[0]}"
    elif not pd.isna(row['level_4']):  
        return f"{row['Hierarchy_ID'].rsplit('.', 1)[0]}"
    elif not pd.isna(row['level_3']):  
        return f"{row['Hierarchy_ID'].rsplit('.', 1)[0]}"
    elif not pd.isna(row['level_2']):  
        return f"{row['Hierarchy_ID'].rsplit('.', 1)[0]}"
    elif not pd.isna(row['level_1']): 
        return None
    else:
        return None


df['Parent_ID'] = df.apply(assign_parent_id, axis=1)

# %%
df['metric_id'] = range(1, len(df) + 1)

# %%
df['metric_sequence_num'] = df.groupby('Operating System Type').cumcount() + 1

# %%
df['metric_seqno'] = df['display_names'].map(metric_seqnum_mapping)
#df['metric_seqno'] = df.groupby('Feature').cumcount() + 1

# %%
def calculate_level_no(row):
   
    if pd.isna(row['Hierarchy_ID']) or pd.isna(row['Parent_ID']):
        return 1
    
   
    return row['Hierarchy_ID'].count('.') + 1


df['level_no'] = df.apply(calculate_level_no, axis=1)

# %%
feature_names = df['Feature'].unique()
feature_mapping = {feature_name: idx + 1 for idx, feature_name in enumerate(feature_names)}

df['feature_id'] = df['Feature'].map(feature_mapping)

# %%
# Create 'feature_seq_num' column based on the dictionary
df['feature_seq_num'] = df['Feature'].map(feature_seqno_mapping)

# %%
df['create_dt'] = pd.to_datetime('today').normalize().date()

# %%
df = df.rename(columns={'Parent_ID': 'parent_id_old'})

# %%
def calculate_parent_id(row, df):
    
    if pd.isna(row['Hierarchy_ID']):
        return None
   
    hierarchy_parts = row['Hierarchy_ID'].rsplit('.', 1)
    if len(hierarchy_parts) > 1:
       
        parent_hierarchy = hierarchy_parts[0]
        
        parent_row = df[df['Hierarchy_ID'] == parent_hierarchy]
        if not parent_row.empty:
            return parent_row['metric_id'].values[0]

    return None

df['parent_id'] = df.apply(calculate_parent_id, axis=1, df=df)


df.loc[df['Hierarchy_ID'].isna(), 'parent_id'] = None

# %%
df = df.rename(columns={
    'Metrics': 'metrics',
    'Operating System Type': 'operating_system_type',
    'Feature': 'feature_name',
    'Operating System Type': 'operating_system_type',
    'Feature': 'feature_name',
    'Operating System Type': 'operating_system_type',
    'Hierarchy_ID': 'hierarchy_id',
})

# %%
df.shape
# Out:
# (463, 111)

# %%
print(list(df.columns))
# Out:
# ['metrics', 'operating_system_type', '29-08-2024', '30-08-2024', '31-08-2024', '01-09-2024', '02-09-2024', '03-09-2024', '04-09-2024', '05-09-2024', '06-09-2024', '07-09-2024', '08-09-2024', '09-09-2024', '10-09-2024', '11-09-2024', '12-09-2024', '13-09-2024', '14-09-2024', '15-09-2024', '16-09-2024', '17-09-2024', '18-09-2024', '19-09-2024', '20-09-2024', '21-09-2024', '22-09-2024', '23-09-2024', '24-09-2024', '25-09-2024', '26-09-2024', '27-09-2024', '28-09-2024', '29-09-2024', '30-09-2024', '01-10-2024', '02-10-2024', '03-10-2024', '04-10-2024', '05-10-2024', '06-10-2024', '07-10-2024', '08-10-2024', '09-10-2024', '10-10-2024', '11-10-2024', '12-10-2024', '13-10-2024', '14-10-2024', '15-10-2024', '16-10-2024', '17-10-2024', '18-10-2024', '19-10-2024', '20-10-2024', '21-10-2024', '22-10-2024', '23-10-2024', '24-10-2024', '25-10-2024', '26-10-2024', '27-10-2024', '28-10-2024', '29-10-2024', '30-10-2024', '31-10-2024', '01-11-2024', '02-11-2024', '03-11-2024', '04-11-2024', '05-11-2024', '06-11-2024', '07-11-2024', '08-11-2024', '09-11-2024', '10-11-2024', '11-11-2024', '12-11-2024', '13-11-2024', '14-11-2024', '15-11-2024', '16-11-2024', '17-11-2024', '18-11-2024', '19-11-2024', '20-11-2024', '21-11-2024', '22-11-2024', '23-11-2024', '24-11-2024', '25-11-2024', '26-11-2024', 'display_names', 'metric_nature', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'feature_name', 'unique_identifier', 'hierarchy_id', 'parent_id_old', 'metric_id', 'metric_sequence_num', 'metric_seqno', 'level_no', 'feature_id', 'feature_seq_num', 'create_dt', 'parent_id']

# %%
first_table_columns = ['metric_id', 'metrics', 'display_names', 'operating_system_type', 'feature_name', 'unique_identifier', 'level_1', 'level_2', 'level_3', 'level_4','level_5', 'hierarchy_id', 'parent_id_old', 'metric_sequence_num', 'metric_seqno', 'level_no', 'feature_id', 'feature_seq_num', 'parent_id', 'metric_nature', 'create_dt' ]
first_table_df = df[first_table_columns]

# %%
#first_table_df.to_csv(r'D:\Healthsore Data\table_1_data_all_features.csv', index = False)

# %%
def is_date_column(col_name):
    date_formats = ['%d-%m-%Y']
    for fmt in date_formats:
        try:
            pd.to_datetime(col_name, format=fmt)
            return True
        except ValueError:
            continue  # Try the next format
    return False

# Filter columns with date format 'm/d/Y'
date_columns = [col for col in df.columns if is_date_column(col)]

# %%
second_table_columns1 = ['metric_id', 'create_dt', 'metrics', 'operating_system_type']
second_table_columns = second_table_columns1 + date_columns
second_table_df = df[second_table_columns]

# %%
filtered_date_columns = second_table_df.columns[4:].to_list()

# %%
id_vars = ['metric_id', 'create_dt']

# %%
second_table_df_melted = second_table_df.melt(id_vars = id_vars, value_vars = filtered_date_columns, var_name = 'Date', value_name = 'Value')

# %%
second_table_df_melted.shape
# Out:
# (41670, 4)

# %%
#second_table_df_melted.to_csv(r'D:\Healthsore Data\table_2_data_all_features.csv', index = False)

# %%
sample_df = df[df['feature_name'].isin(['SMART HELP', 'RESET MODEM', 'RESET TV BOX'])]
sample_df.shape
# Out:
# (68, 111)

# %%
def calculate_percentage(df, datecolumns, metricid, parentid):
    # Ensure these columns exist in the DataFrame
    if metricid not in df.columns or parentid not in df.columns:
        raise ValueError(f"'{metricid}' or '{parentid}' columns not found in DataFrame.")
    
    # Create a copy of the DataFrame to avoid setting on a view
    df = df.copy()
    
    # Iterate through each row and calculate the percentage for each DATE column
    for idx, row in df.iterrows():
        # Iterate through all the DATE columns
        for date_col in datecolumns:
            # Get the numerator (DATE value)
            numerator = row[date_col]
            
            # Get the parent hierarchy ID
            parent_id = row[parentid]
            
            # Check if the parent is empty
            if pd.isna(parent_id) or parent_id == "":
                # If the PARENTID is empty, keep the original DATE value
                percentage = numerator  # Assuming 100% when no parent is found
            else:
                # Find the row where HIERARCHYID == parent_hierarchyid to get the parent's DATE value
                parent_row = df[df[metricid] == parent_id]
                
                # If the parent exists, get the parent's DATE value for the current DATE column
                if not parent_row.empty:
                    denominator = parent_row[date_col].values[0]
                else:
                    denominator = 0  # In case no parent is found, avoid division by zero
                
                # Calculate the percentage
                if denominator != 0:
                    percentage = (numerator / denominator) * 100
                else:
                    percentage = 0  # To handle division by zero if no parent found
                
            # Round to 3 decimal places
            percentage = round(percentage, 3)
            
            # Add the percentage to the DataFrame in a new column
            percentage_column_name = f"{date_col} PERCENTAGE"
            if percentage_column_name not in df.columns:
                df[percentage_column_name] = None  # Initialize the column safely
            
            # Set the percentage for the current row and current date column using .loc
            df.loc[idx, percentage_column_name] = percentage

    return df

# %%
percentage_df = calculate_percentage(sample_df, date_columns, 'metric_id', 'parent_id')
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 100)
percentage_df.head()
# Out:
#                                         metrics operating_system_type  \
# 140                  DR_Reset Modem - Home Page             Apple iOS
# 141  DR_Reset Modem - Started Rebooting Process             Apple iOS
# 142         DR_Reset Modem - Rebooting Complete             Apple iOS
# 143       DR_Reset Modem - Rebooting Incomplete             Apple iOS
# 144                 DR_Reset Modem - Agent Chat             Apple iOS
#
#     29-08-2024 30-08-2024 31-08-2024 01-09-2024 02-09-2024 03-09-2024  \
# 140     5306.0     5499.0     5415.0     5353.0     5588.0     5238.0
# 141     4839.0     5008.0     4930.0     4904.0     5080.0     4732.0
# 142     1478.0     1530.0     1535.0     1562.0     1589.0     1465.0
# 143     2201.0     2341.0     2328.0     2287.0     2338.0     2179.0
# 144      705.0      738.0      766.0      751.0      696.0      696.0
#
#     04-09-2024 05-09-2024 06-09-2024 07-09-2024 08-09-2024 09-09-2024  \
# 140     5630.0     6204.0     6118.0     5738.0     5762.0     5322.0
# 141     5096.0     5699.0     5600.0     5194.0     5333.0     4881.0
# 142     1423.0     1566.0     1622.0     1636.0     1636.0     1572.0
# 143     2630.0     2931.0     2749.0     2479.0     2440.0     2125.0
# 144      836.0      963.0      921.0      796.0      783.0      689.0
#
#     10-09-2024 11-09-2024 12-09-2024 13-09-2024 14-09-2024 15-09-2024  \
# 140     5746.0     4950.0     4861.0     4955.0     5519.0     5737.0
# 141     5208.0     4401.0     4417.0     4500.0     5044.0     5245.0
# 142     1628.0     1357.0     1377.0     1437.0     1602.0     1715.0
# 143     2374.0     2078.0     1962.0     2052.0     2287.0     2389.0
# 144      764.0      699.0      664.0      673.0      766.0      831.0
#
#     16-09-2024 17-09-2024 18-09-2024 19-09-2024 20-09-2024 21-09-2024  \
# 140     5066.0     4975.0     5269.0     4883.0     5107.0     5354.0
# 141     4633.0     4489.0     4834.0     4454.0     4614.0     4873.0
# 142     1474.0     1353.0     1569.0     1332.0     1453.0     1480.0
# 143     2115.0     2045.0     2185.0     2097.0     2073.0     2243.0
# 144      696.0      669.0      676.0      676.0      706.0      749.0
#
#     22-09-2024 23-09-2024 24-09-2024 25-09-2024 26-09-2024 27-09-2024  \
# 140     5501.0     4933.0     5254.0     5066.0     5078.0     4948.0
# 141     5068.0     4455.0     4816.0     4620.0     4658.0     4471.0
# 142     1635.0     1458.0     1355.0     1538.0     1522.0     1448.0
# 143     2280.0     1935.0     2312.0     2068.0     2097.0     1978.0
# 144      680.0      653.0      741.0      659.0      682.0      694.0
#
#     28-09-2024 29-09-2024 30-09-2024 01-10-2024 02-10-2024 03-10-2024  \
# 140     5244.0     5526.0     5932.0     5742.0     5079.0     4916.0
# 141     4808.0     5081.0     5486.0     5249.0     4596.0     4473.0
# 142     1513.0     1625.0     1959.0     1709.0     1473.0     1414.0
# 143     2219.0     2251.0     2327.0     2333.0     2141.0     2043.0
# 144      712.0      705.0      733.0      788.0      738.0      644.0
#
#     04-10-2024 05-10-2024 06-10-2024 07-10-2024 08-10-2024 09-10-2024  \
# 140     5167.0     5095.0     5282.0     4811.0     4788.0     5203.0
# 141     4701.0     4682.0     4851.0     4405.0     4373.0     4783.0
# 142     1487.0     1464.0     1593.0     1419.0     1349.0     1562.0
# 143     2076.0     2118.0     2103.0     1979.0     1965.0     2102.0
# 144      658.0      693.0      656.0      646.0      633.0      713.0
#
#     10-10-2024 11-10-2024 12-10-2024 13-10-2024 14-10-2024 15-10-2024  \
# 140     4647.0     4820.0     4883.0     4430.0     4915.0     4860.0
# 141     4286.0     4404.0     4445.0     4061.0     4479.0     4407.0
# 142     1460.0     1410.0     1439.0     1341.0     1501.0     1385.0
# 143     1846.0     1935.0     1910.0     1718.0     2006.0     2018.0
# 144      606.0      620.0      646.0      581.0      625.0      645.0
#
#     16-10-2024 17-10-2024 18-10-2024 19-10-2024 20-10-2024 21-10-2024  \
# 140     5033.0     4824.0     5393.0     5422.0     5324.0     4951.0
# 141     4644.0     4434.0     4948.0     4993.0     4942.0     4611.0
# 142     1543.0     1471.0     1595.0     1628.0     1580.0     1506.0
# 143     2035.0     1909.0     2210.0     2254.0     2247.0     2021.0
# 144      636.0      586.0      700.0      686.0      687.0      639.0
#
#     22-10-2024 23-10-2024 24-10-2024 25-10-2024 26-10-2024 27-10-2024  \
# 140     4931.0     4573.0     4797.0     4963.0     4711.0     4791.0
# 141     4547.0     4184.0     4409.0     4537.0     4337.0     4386.0
# 142     1465.0     1309.0     1419.0     1532.0     1467.0     1455.0
# 143     2005.0     1928.0     1926.0     1944.0     1874.0     1856.0
# 144      635.0      562.0      561.0      617.0      601.0      547.0
#
#     28-10-2024 29-10-2024 30-10-2024 31-10-2024 01-11-2024 02-11-2024  \
# 140     4715.0     4702.0     4636.0     4508.0     4668.0     5393.0
# 141     3719.0     3966.0     4345.0     4259.0     4377.0     5049.0
# 142     1200.0     1297.0     1386.0     1331.0     1406.0     1664.0
# 143     1712.0     1778.0     1940.0     1951.0     2000.0     2362.0
# 144      541.0      530.0      598.0      660.0      709.0      760.0
#
#     03-11-2024 04-11-2024 05-11-2024 06-11-2024 07-11-2024 08-11-2024  \
# 140     5706.0     4926.0     4612.0     4219.0     4317.0     5308.0
# 141     5394.0     4674.0     4326.0     3970.0     4055.0     4613.0
# 142     1679.0     1476.0     1395.0     1283.0     1309.0     1458.0
# 143     2405.0     2119.0     1896.0     1775.0     1815.0     2126.0
# 144      795.0      668.0      561.0      534.0      602.0      755.0
#
#     09-11-2024 10-11-2024 11-11-2024 12-11-2024 13-11-2024 14-11-2024  \
# 140     5262.0     5030.0     4957.0     4926.0     4920.0     5601.0
# 141     4977.0     4754.0     4645.0     4646.0     4618.0     5269.0
# 142     1489.0     1434.0     1419.0     1429.0     1443.0     1549.0
# 143     2429.0     2258.0     2210.0     2212.0     2137.0     2522.0
# 144      844.0      781.0      683.0      770.0      658.0      779.0
#
#     15-11-2024 16-11-2024 17-11-2024 18-11-2024 19-11-2024 20-11-2024  \
# 140     8941.0     5652.0     5370.0     4983.0     4760.0     4617.0
# 141     8500.0     5303.0     5035.0     4677.0     4459.0     4303.0
# 142     3570.0     1821.0     1650.0     1490.0     1357.0     1371.0
# 143     3071.0     2470.0     2316.0     2177.0     2127.0     2037.0
# 144      961.0      806.0      689.0      699.0      668.0      638.0
#
#     21-11-2024 22-11-2024 23-11-2024 24-11-2024 25-11-2024 26-11-2024  \
# 140     4981.0     5001.0     5260.0     5455.0     4976.0     4739.0
# 141     4543.0     4674.0     4927.0     5130.0     4692.0     4426.0
# 142     1403.0     1374.0     1476.0     1524.0     1443.0     1262.0
# 143     2155.0     2229.0     2446.0     2481.0     2176.0     2098.0
# 144      668.0      694.0      882.0      823.0      734.0      691.0
#
#                         display_names metric_nature  \
# 140     Reset Modem Start Page Visits      Positive
# 141             Started Reset Process      Positive
# 142            Reset Process Complete      Positive
# 143          Reset Process Incomplete      Negative
# 144  Reset_Modem Interacted with Chat      Negative
#
#                            level_1                level_2  \
# 140  Reset Modem Start Page Visits                   None
# 141                           None  Started Reset Process
# 142                           None                   None
# 143                           None                   None
# 144                           None                   None
#
#                               level_3 level_4 level_5 feature_name  \
# 140                              None    None    None  RESET MODEM
# 141                              None    None    None  RESET MODEM
# 142            Reset Process Complete    None    None  RESET MODEM
# 143          Reset Process Incomplete    None    None  RESET MODEM
# 144  Reset_Modem Interacted with Chat    None    None  RESET MODEM
#
#     unique_identifier        hierarchy_id     parent_id_old  metric_id  \
# 140                RM      Apple iOS_RM_1              None        141
# 141                RM    Apple iOS_RM_1.1    Apple iOS_RM_1        142
# 142                RM  Apple iOS_RM_1.1.1  Apple iOS_RM_1.1        143
# 143                RM  Apple iOS_RM_1.1.2  Apple iOS_RM_1.1        144
# 144                RM  Apple iOS_RM_1.1.3  Apple iOS_RM_1.1        145
#
#      metric_sequence_num metric_seqno  level_no  feature_id feature_seq_num  \
# 140                  141            1         1          11               6
# 141                  142            2         2          11               6
# 142                  143            3         3          11               6
# 143                  144            4         3          11               6
# 144                  145            5         3          11               6
#
#       create_dt  parent_id 29-08-2024 PERCENTAGE 30-08-2024 PERCENTAGE  \
# 140  2025-01-29        NaN                5306.0                5499.0
# 141  2025-01-29      141.0                91.199                91.071
# 142  2025-01-29      142.0                30.544                30.551
# 143  2025-01-29      142.0                45.485                46.745
# 144  2025-01-29      142.0                14.569                14.736
#
#     31-08-2024 PERCENTAGE 01-09-2024 PERCENTAGE 02-09-2024 PERCENTAGE  \
# 140                5415.0                5353.0                5588.0
# 141                91.043                91.612                90.909
# 142                31.136                31.852                 31.28
# 143                47.221                46.635                46.024
# 144                15.538                15.314                13.701
#
#     03-09-2024 PERCENTAGE 04-09-2024 PERCENTAGE 05-09-2024 PERCENTAGE  \
# 140                5238.0                5630.0                6204.0
# 141                 90.34                90.515                 91.86
# 142                30.959                27.924                27.479
# 143                46.048                51.609                 51.43
# 144                14.708                16.405                16.898
#
#     06-09-2024 PERCENTAGE 07-09-2024 PERCENTAGE 08-09-2024 PERCENTAGE  \
# 140                6118.0                5738.0                5762.0
# 141                91.533                90.519                92.555
# 142                28.964                31.498                30.677
# 143                49.089                47.728                45.753
# 144                16.446                15.325                14.682
#
#     09-09-2024 PERCENTAGE 10-09-2024 PERCENTAGE 11-09-2024 PERCENTAGE  \
# 140                5322.0                5746.0                4950.0
# 141                91.714                90.637                88.909
# 142                32.207                 31.26                30.834
# 143                43.536                45.584                47.217
# 144                14.116                 14.67                15.883
#
#     12-09-2024 PERCENTAGE 13-09-2024 PERCENTAGE 14-09-2024 PERCENTAGE  \
# 140                4861.0                4955.0                5519.0
# 141                90.866                90.817                91.393
# 142                31.175                31.933                31.761
# 143                44.419                  45.6                45.341
# 144                15.033                14.956                15.186
#
#     15-09-2024 PERCENTAGE 16-09-2024 PERCENTAGE 17-09-2024 PERCENTAGE  \
# 140                5737.0                5066.0                4975.0
# 141                91.424                91.453                90.231
# 142                32.698                31.815                 30.14
# 143                45.548                45.651                45.556
# 144                15.844                15.023                14.903
#
#     18-09-2024 PERCENTAGE 19-09-2024 PERCENTAGE 20-09-2024 PERCENTAGE  \
# 140                5269.0                4883.0                5107.0
# 141                91.744                91.214                90.347
# 142                32.458                29.906                31.491
# 143                45.201                47.081                44.928
# 144                13.984                15.177                15.301
#
#     21-09-2024 PERCENTAGE 22-09-2024 PERCENTAGE 23-09-2024 PERCENTAGE  \
# 140                5354.0                5501.0                4933.0
# 141                91.016                92.129                 90.31
# 142                30.371                32.261                32.727
# 143                46.029                44.988                43.434
# 144                 15.37                13.418                14.658
#
#     24-09-2024 PERCENTAGE 25-09-2024 PERCENTAGE 26-09-2024 PERCENTAGE  \
# 140                5254.0                5066.0                5078.0
# 141                91.663                91.196                91.729
# 142                28.135                 33.29                32.675
# 143                48.007                44.762                45.019
# 144                15.386                14.264                14.641
#
#     27-09-2024 PERCENTAGE 28-09-2024 PERCENTAGE 29-09-2024 PERCENTAGE  \
# 140                4948.0                5244.0                5526.0
# 141                 90.36                91.686                91.947
# 142                32.386                31.468                31.982
# 143                44.241                46.152                44.302
# 144                15.522                14.809                13.875
#
#     30-09-2024 PERCENTAGE 01-10-2024 PERCENTAGE 02-10-2024 PERCENTAGE  \
# 140                5932.0                5742.0                5079.0
# 141                92.481                91.414                 90.49
# 142                35.709                32.559                 32.05
# 143                42.417                44.447                46.584
# 144                13.361                15.012                16.057
#
#     03-10-2024 PERCENTAGE 04-10-2024 PERCENTAGE 05-10-2024 PERCENTAGE  \
# 140                4916.0                5167.0                5095.0
# 141                90.989                90.981                91.894
# 142                31.612                31.632                31.269
# 143                45.674                44.161                45.237
# 144                14.397                13.997                14.801
#
#     06-10-2024 PERCENTAGE 07-10-2024 PERCENTAGE 08-10-2024 PERCENTAGE  \
# 140                5282.0                4811.0                4788.0
# 141                 91.84                91.561                91.332
# 142                32.839                32.213                30.848
# 143                43.352                44.926                44.935
# 144                13.523                14.665                14.475
#
#     09-10-2024 PERCENTAGE 10-10-2024 PERCENTAGE 11-10-2024 PERCENTAGE  \
# 140                5203.0                4647.0                4820.0
# 141                91.928                92.232                91.369
# 142                32.657                34.064                32.016
# 143                43.947                 43.07                43.937
# 144                14.907                14.139                14.078
#
#     12-10-2024 PERCENTAGE 13-10-2024 PERCENTAGE 14-10-2024 PERCENTAGE  \
# 140                4883.0                4430.0                4915.0
# 141                 91.03                 91.67                91.129
# 142                32.373                33.021                33.512
# 143                 42.97                42.305                44.787
# 144                14.533                14.307                13.954
#
#     15-10-2024 PERCENTAGE 16-10-2024 PERCENTAGE 17-10-2024 PERCENTAGE  \
# 140                4860.0                5033.0                4824.0
# 141                90.679                92.271                91.915
# 142                31.427                33.226                33.175
# 143                45.791                 43.82                43.054
# 144                14.636                13.695                13.216
#
#     18-10-2024 PERCENTAGE 19-10-2024 PERCENTAGE 20-10-2024 PERCENTAGE  \
# 140                5393.0                5422.0                5324.0
# 141                91.749                92.088                92.825
# 142                32.235                32.606                31.971
# 143                44.665                45.143                45.467
# 144                14.147                13.739                13.901
#
#     21-10-2024 PERCENTAGE 22-10-2024 PERCENTAGE 23-10-2024 PERCENTAGE  \
# 140                4951.0                4931.0                4573.0
# 141                93.133                92.213                91.494
# 142                32.661                32.219                31.286
# 143                 43.83                44.095                 46.08
# 144                13.858                13.965                13.432
#
#     24-10-2024 PERCENTAGE 25-10-2024 PERCENTAGE 26-10-2024 PERCENTAGE  \
# 140                4797.0                4963.0                4711.0
# 141                91.912                91.416                92.061
# 142                32.184                33.767                33.825
# 143                43.683                42.848                 43.21
# 144                12.724                13.599                13.858
#
#     27-10-2024 PERCENTAGE 28-10-2024 PERCENTAGE 29-10-2024 PERCENTAGE  \
# 140                4791.0                4715.0                4702.0
# 141                91.547                78.876                84.347
# 142                33.174                32.267                32.703
# 143                42.316                46.034                44.831
# 144                12.472                14.547                13.364
#
#     30-10-2024 PERCENTAGE 31-10-2024 PERCENTAGE 01-11-2024 PERCENTAGE  \
# 140                4636.0                4508.0                4668.0
# 141                93.723                94.476                93.766
# 142                31.899                31.251                32.122
# 143                44.649                45.809                45.693
# 144                13.763                15.497                16.198
#
#     02-11-2024 PERCENTAGE 03-11-2024 PERCENTAGE 04-11-2024 PERCENTAGE  \
# 140                5393.0                5706.0                4926.0
# 141                93.621                94.532                94.884
# 142                32.957                31.127                31.579
# 143                46.782                44.587                45.336
# 144                15.052                14.739                14.292
#
#     05-11-2024 PERCENTAGE 06-11-2024 PERCENTAGE 07-11-2024 PERCENTAGE  \
# 140                4612.0                4219.0                4317.0
# 141                93.799                94.098                93.931
# 142                32.247                32.317                32.281
# 143                43.828                 44.71                 44.76
# 144                12.968                13.451                14.846
#
#     08-11-2024 PERCENTAGE 09-11-2024 PERCENTAGE 10-11-2024 PERCENTAGE  \
# 140                5308.0                5262.0                5030.0
# 141                86.907                94.584                94.513
# 142                31.606                29.918                30.164
# 143                46.087                48.805                47.497
# 144                16.367                16.958                16.428
#
#     11-11-2024 PERCENTAGE 12-11-2024 PERCENTAGE 13-11-2024 PERCENTAGE  \
# 140                4957.0                4926.0                4920.0
# 141                93.706                94.316                93.862
# 142                30.549                30.758                31.247
# 143                47.578                47.611                46.275
# 144                14.704                16.573                14.249
#
#     14-11-2024 PERCENTAGE 15-11-2024 PERCENTAGE 16-11-2024 PERCENTAGE  \
# 140                5601.0                8941.0                5652.0
# 141                94.072                95.068                93.825
# 142                29.398                  42.0                34.339
# 143                47.865                36.129                46.577
# 144                14.785                11.306                15.199
#
#     17-11-2024 PERCENTAGE 18-11-2024 PERCENTAGE 19-11-2024 PERCENTAGE  \
# 140                5370.0                4983.0                4760.0
# 141                93.762                93.859                93.676
# 142                32.771                31.858                30.433
# 143                45.998                46.547                47.701
# 144                13.684                14.945                14.981
#
#     20-11-2024 PERCENTAGE 21-11-2024 PERCENTAGE 22-11-2024 PERCENTAGE  \
# 140                4617.0                4981.0                5001.0
# 141                93.199                91.207                93.461
# 142                31.861                30.883                29.397
# 143                47.339                47.436                47.689
# 144                14.827                14.704                14.848
#
#     23-11-2024 PERCENTAGE 24-11-2024 PERCENTAGE 25-11-2024 PERCENTAGE  \
# 140                5260.0                5455.0                4976.0
# 141                93.669                94.042                94.293
# 142                29.957                29.708                30.754
# 143                49.645                48.363                46.377
# 144                17.901                16.043                15.644
#
#     26-11-2024 PERCENTAGE
# 140                4739.0
# 141                93.395
# 142                28.513
# 143                47.402
# 144                15.612

# %%
percentage_df.shape
# Out:
# (68, 201)

# %%
id_columns = ['create_dt', 'metric_id', 'feature_id', 'feature_seq_num', 'metric_sequence_num', 'metric_seqno','level_no', 'parent_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names', 'operating_system_type', 'metric_nature']

# %%
# List of columns that contain "PERCENTAGE"
percentage_columns = [col for col in percentage_df.columns if 'PERCENTAGE' in col]

# %%
percent_df = percentage_df[id_columns + percentage_columns]

# %%
# Rename columns to remove the word "PERCENTAGE"
percent_df.columns = [col.replace(" PERCENTAGE", "") if "PERCENTAGE" in col else col for col in percent_df.columns]

# %%
percent_df.shape
# Out:
# (68, 104)

# %%
percent_df.head()
# Out:
#       create_dt  metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 140  2025-01-29        141          11               6                  141
# 141  2025-01-29        142          11               6                  142
# 142  2025-01-29        143          11               6                  143
# 143  2025-01-29        144          11               6                  144
# 144  2025-01-29        145          11               6                  145
#
#     metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 140            1         1        NaN                RM  RESET MODEM
# 141            2         2      141.0                RM  RESET MODEM
# 142            3         3      142.0                RM  RESET MODEM
# 143            4         3      142.0                RM  RESET MODEM
# 144            5         3      142.0                RM  RESET MODEM
#
#                                         metrics  \
# 140                  DR_Reset Modem - Home Page
# 141  DR_Reset Modem - Started Rebooting Process
# 142         DR_Reset Modem - Rebooting Complete
# 143       DR_Reset Modem - Rebooting Incomplete
# 144                 DR_Reset Modem - Agent Chat
#
#                         display_names operating_system_type metric_nature  \
# 140     Reset Modem Start Page Visits             Apple iOS      Positive
# 141             Started Reset Process             Apple iOS      Positive
# 142            Reset Process Complete             Apple iOS      Positive
# 143          Reset Process Incomplete             Apple iOS      Negative
# 144  Reset_Modem Interacted with Chat             Apple iOS      Negative
#
#     29-08-2024 30-08-2024 31-08-2024 01-09-2024 02-09-2024 03-09-2024  \
# 140     5306.0     5499.0     5415.0     5353.0     5588.0     5238.0
# 141     91.199     91.071     91.043     91.612     90.909      90.34
# 142     30.544     30.551     31.136     31.852      31.28     30.959
# 143     45.485     46.745     47.221     46.635     46.024     46.048
# 144     14.569     14.736     15.538     15.314     13.701     14.708
#
#     04-09-2024 05-09-2024 06-09-2024 07-09-2024 08-09-2024 09-09-2024  \
# 140     5630.0     6204.0     6118.0     5738.0     5762.0     5322.0
# 141     90.515      91.86     91.533     90.519     92.555     91.714
# 142     27.924     27.479     28.964     31.498     30.677     32.207
# 143     51.609      51.43     49.089     47.728     45.753     43.536
# 144     16.405     16.898     16.446     15.325     14.682     14.116
#
#     10-09-2024 11-09-2024 12-09-2024 13-09-2024 14-09-2024 15-09-2024  \
# 140     5746.0     4950.0     4861.0     4955.0     5519.0     5737.0
# 141     90.637     88.909     90.866     90.817     91.393     91.424
# 142      31.26     30.834     31.175     31.933     31.761     32.698
# 143     45.584     47.217     44.419       45.6     45.341     45.548
# 144      14.67     15.883     15.033     14.956     15.186     15.844
#
#     16-09-2024 17-09-2024 18-09-2024 19-09-2024 20-09-2024 21-09-2024  \
# 140     5066.0     4975.0     5269.0     4883.0     5107.0     5354.0
# 141     91.453     90.231     91.744     91.214     90.347     91.016
# 142     31.815      30.14     32.458     29.906     31.491     30.371
# 143     45.651     45.556     45.201     47.081     44.928     46.029
# 144     15.023     14.903     13.984     15.177     15.301      15.37
#
#     22-09-2024 23-09-2024 24-09-2024 25-09-2024 26-09-2024 27-09-2024  \
# 140     5501.0     4933.0     5254.0     5066.0     5078.0     4948.0
# 141     92.129      90.31     91.663     91.196     91.729      90.36
# 142     32.261     32.727     28.135      33.29     32.675     32.386
# 143     44.988     43.434     48.007     44.762     45.019     44.241
# 144     13.418     14.658     15.386     14.264     14.641     15.522
#
#     28-09-2024 29-09-2024 30-09-2024 01-10-2024 02-10-2024 03-10-2024  \
# 140     5244.0     5526.0     5932.0     5742.0     5079.0     4916.0
# 141     91.686     91.947     92.481     91.414      90.49     90.989
# 142     31.468     31.982     35.709     32.559      32.05     31.612
# 143     46.152     44.302     42.417     44.447     46.584     45.674
# 144     14.809     13.875     13.361     15.012     16.057     14.397
#
#     04-10-2024 05-10-2024 06-10-2024 07-10-2024 08-10-2024 09-10-2024  \
# 140     5167.0     5095.0     5282.0     4811.0     4788.0     5203.0
# 141     90.981     91.894      91.84     91.561     91.332     91.928
# 142     31.632     31.269     32.839     32.213     30.848     32.657
# 143     44.161     45.237     43.352     44.926     44.935     43.947
# 144     13.997     14.801     13.523     14.665     14.475     14.907
#
#     10-10-2024 11-10-2024 12-10-2024 13-10-2024 14-10-2024 15-10-2024  \
# 140     4647.0     4820.0     4883.0     4430.0     4915.0     4860.0
# 141     92.232     91.369      91.03      91.67     91.129     90.679
# 142     34.064     32.016     32.373     33.021     33.512     31.427
# 143      43.07     43.937      42.97     42.305     44.787     45.791
# 144     14.139     14.078     14.533     14.307     13.954     14.636
#
#     16-10-2024 17-10-2024 18-10-2024 19-10-2024 20-10-2024 21-10-2024  \
# 140     5033.0     4824.0     5393.0     5422.0     5324.0     4951.0
# 141     92.271     91.915     91.749     92.088     92.825     93.133
# 142     33.226     33.175     32.235     32.606     31.971     32.661
# 143      43.82     43.054     44.665     45.143     45.467      43.83
# 144     13.695     13.216     14.147     13.739     13.901     13.858
#
#     22-10-2024 23-10-2024 24-10-2024 25-10-2024 26-10-2024 27-10-2024  \
# 140     4931.0     4573.0     4797.0     4963.0     4711.0     4791.0
# 141     92.213     91.494     91.912     91.416     92.061     91.547
# 142     32.219     31.286     32.184     33.767     33.825     33.174
# 143     44.095      46.08     43.683     42.848      43.21     42.316
# 144     13.965     13.432     12.724     13.599     13.858     12.472
#
#     28-10-2024 29-10-2024 30-10-2024 31-10-2024 01-11-2024 02-11-2024  \
# 140     4715.0     4702.0     4636.0     4508.0     4668.0     5393.0
# 141     78.876     84.347     93.723     94.476     93.766     93.621
# 142     32.267     32.703     31.899     31.251     32.122     32.957
# 143     46.034     44.831     44.649     45.809     45.693     46.782
# 144     14.547     13.364     13.763     15.497     16.198     15.052
#
#     03-11-2024 04-11-2024 05-11-2024 06-11-2024 07-11-2024 08-11-2024  \
# 140     5706.0     4926.0     4612.0     4219.0     4317.0     5308.0
# 141     94.532     94.884     93.799     94.098     93.931     86.907
# 142     31.127     31.579     32.247     32.317     32.281     31.606
# 143     44.587     45.336     43.828      44.71      44.76     46.087
# 144     14.739     14.292     12.968     13.451     14.846     16.367
#
#     09-11-2024 10-11-2024 11-11-2024 12-11-2024 13-11-2024 14-11-2024  \
# 140     5262.0     5030.0     4957.0     4926.0     4920.0     5601.0
# 141     94.584     94.513     93.706     94.316     93.862     94.072
# 142     29.918     30.164     30.549     30.758     31.247     29.398
# 143     48.805     47.497     47.578     47.611     46.275     47.865
# 144     16.958     16.428     14.704     16.573     14.249     14.785
#
#     15-11-2024 16-11-2024 17-11-2024 18-11-2024 19-11-2024 20-11-2024  \
# 140     8941.0     5652.0     5370.0     4983.0     4760.0     4617.0
# 141     95.068     93.825     93.762     93.859     93.676     93.199
# 142       42.0     34.339     32.771     31.858     30.433     31.861
# 143     36.129     46.577     45.998     46.547     47.701     47.339
# 144     11.306     15.199     13.684     14.945     14.981     14.827
#
#     21-11-2024 22-11-2024 23-11-2024 24-11-2024 25-11-2024 26-11-2024
# 140     4981.0     5001.0     5260.0     5455.0     4976.0     4739.0
# 141     91.207     93.461     93.669     94.042     94.293     93.395
# 142     30.883     29.397     29.957     29.708     30.754     28.513
# 143     47.436     47.689     49.645     48.363     46.377     47.402
# 144     14.704     14.848     17.901     16.043     15.644     15.612

# %%
def calculate_both(df, metricid, parentid):
    """
    Generate new rows for each unique display_name based on given conditions.

    Args:
    - df (DataFrame): Input DataFrame containing the original data.

    Returns:
    - DataFrame: Updated DataFrame with newly calculated rows.
    """
    new_rows = []  # Store new rows
    seq_num = 1  # Sequential ID for metric_id

    for display_name in df['display_names'].unique():
        # Filter rows for the current display_name
        display_df = df[df['display_names'] == display_name]
            
        # Case 1: If `parent_id_old` has null or empty values
        if display_df[parentid].isnull().any() or display_df[parentid].eq('').any():
            # Sum of `Apple iOS` and `Google Android` for `parent_id_old` being null
            ios_rows = display_df[display_df["operating_system_type"] == "Apple iOS"]
            android_rows = display_df[display_df["operating_system_type"] == "Google Android"]
            
            # Calculate numerator using `where` to avoid downcasting issues
            ios_sums = ios_rows[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            android_sums = android_rows[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            numerator = ios_sums + android_sums
            
            # Store numerator in new row, rounded to 3 decimal places
            new_row_values = numerator.sum(axis=0).fillna(0).apply(lambda x: round(x, 3)).to_dict()
        else:
            # Case 2: If `parent_id_old` is not null
            ios_rows = display_df[(display_df["operating_system_type"] == "Apple iOS") & 
                                  (display_df[parentid].notna()) & 
                                  (display_df[parentid] != '')]
            android_rows = display_df[(display_df["operating_system_type"] == "Google Android") & 
                                      (display_df[parentid].notna()) & 
                                      (display_df[parentid] != '')]
            
            # Calculate numerator using `where` to avoid downcasting issues
            ios_sums = ios_rows[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            android_sums = android_rows[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            numerator = ios_sums + android_sums
            
            # Filter rows where `parent_id_old` matches `hierarchy_id`
            filtered_data = df[df[metricid].isin(display_df[parentid])]
            ios_data = filtered_data[filtered_data['operating_system_type'] == "Apple iOS"]
            android_data = filtered_data[filtered_data['operating_system_type'] == "Google Android"]

            # Calculate denominator
            ios_sums_denom = ios_data[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            android_sums_denom = android_data[date_columns].apply(pd.to_numeric, errors='coerce').reset_index(drop=True)
            denominator = ios_sums_denom + android_sums_denom

            # Calculate result as percentage
            result = (numerator / denominator) * 100 if not denominator.empty else pd.DataFrame(0, columns=date_columns, index=numerator.index)
            result = result.round(3)  # Round result to 3 decimal places
            new_row_values = result.sum(axis=0).fillna(0).apply(lambda x: round(x, 3)).to_dict()

        # Create the new row for the current display_name
        new_row = {
            'display_names': display_name,
            'operating_system_type': 'Both',
            'metric_id': f'100000{seq_num}'
        }
        # Add calculated values to the new row
        new_row.update(new_row_values)
        new_rows.append(new_row)
        seq_num += 1

    # Append new rows to the original DataFrame
    new_rows_df = pd.DataFrame(new_rows)
    result_df = pd.concat([df, new_rows_df], ignore_index=True)

    # Reset index
    result_df.reset_index(drop=True, inplace=True)
    return new_rows_df

# %%
both_calc_df = calculate_both(sample_df,'metric_id', 'parent_id')
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 300)      # Show 100 rows
both_calc_df.head(5)
# Out:
#                       display_names operating_system_type metric_id  \
# 0     Reset Modem Start Page Visits                  Both   1000001
# 1             Started Reset Process                  Both   1000002
# 2            Reset Process Complete                  Both   1000003
# 3          Reset Process Incomplete                  Both   1000004
# 4  Reset_Modem Interacted with Chat                  Both   1000005
#
#    29-08-2024  30-08-2024  31-08-2024  01-09-2024  02-09-2024  03-09-2024  \
# 0    7097.000    7306.000    7188.000    7093.000    7314.000    6942.000
# 1      91.306      91.213      91.180      91.696      91.045      90.521
# 2      30.694      30.222      30.607      31.365      30.996      30.442
# 3      42.639      43.923      44.583      43.881      42.874      43.730
# 4      14.120      14.631      15.166      14.699      13.516      14.402
#
#    04-09-2024  05-09-2024  06-09-2024  07-09-2024  08-09-2024  09-09-2024  \
# 0    7552.000    8274.000    7993.000    7568.000    7650.000    7100.000
# 1      90.784      91.624      91.618      90.803      92.902      91.845
# 2      27.334      27.397      28.827      31.257      30.083      31.698
# 3      48.775      48.542      46.306      44.761      43.197      40.853
# 4      15.957      16.858      16.237      14.974      14.169      13.464
#
#    10-09-2024  11-09-2024  12-09-2024  13-09-2024  14-09-2024  15-09-2024  \
# 0    7611.000    6706.000    6428.000    6615.000    7345.000    7793.000
# 1      90.724      88.741      90.884      90.718      91.681      91.428
# 2      30.891      30.331      30.452      31.561      31.155      32.295
# 3      42.911      43.993      42.349      43.076      42.694      42.049
# 4      14.106      15.292      14.772      14.431      14.583      15.663
#
#    16-09-2024  17-09-2024  18-09-2024  19-09-2024  20-09-2024  21-09-2024  \
# 0    6746.000    6558.000    6989.000    6586.000    6798.000    7125.000
# 1      91.625      90.378      91.515      91.193      90.482      90.933
# 2      30.836      30.083      32.051      29.487      31.247      30.159
# 3      43.278      42.416      42.433      44.372      42.156      43.479
# 4      14.658      14.139      13.649      14.602      14.811      14.956
#
#    22-09-2024  23-09-2024  24-09-2024  25-09-2024  26-09-2024  27-09-2024  \
# 0    7310.000    6693.000    6919.000    6793.000    6793.000    6566.000
# 1      92.120      90.811      91.617      91.153      91.874      90.329
# 2      31.868      31.853      28.159      32.187      31.998      31.968
# 3      41.966      41.033      45.149      42.442      42.125      41.662
# 4      13.365      14.182      14.860      14.083      14.164      14.871
#
#    28-09-2024  29-09-2024  30-09-2024  01-10-2024  02-10-2024  03-10-2024  \
# 0    6991.000    7414.000    7974.000    7682.000    6916.000    6714.000
# 1      91.832      92.015      92.300      91.382      90.558      91.346
# 2      30.763      30.944      34.810      31.781      31.646      31.029
# 3      43.988      41.879      38.886      42.293      43.653      43.209
# 4      14.782      13.632      12.785      14.444      15.807      14.137
#
#    04-10-2024  05-10-2024  06-10-2024  07-10-2024  08-10-2024  09-10-2024  \
# 0    6918.000    6884.000    7109.000    6551.000    6429.000    6972.000
# 1      91.472      91.996      91.940      91.589      91.476      91.581
# 2      31.495      31.107      32.375      31.600      29.944      32.545
# 3      41.751      41.986      40.483      41.583      42.969      41.597
# 4      13.812      14.274      13.663      13.933      14.606      14.691
#
#    10-10-2024  11-10-2024  12-10-2024  13-10-2024  14-10-2024  15-10-2024  \
# 0    6265.000    6424.000    6616.000    5860.000    6621.000    6584.000
# 1      92.338      91.469      91.218      91.928      91.270      90.993
# 2      33.258      31.399      32.096      32.987      32.351      31.047
# 3      40.380      41.474      40.199      39.800      42.380      42.864
# 4      13.691      13.870      14.151      13.885      13.917      14.188
#
#    16-10-2024  17-10-2024  18-10-2024  19-10-2024  20-10-2024  21-10-2024  \
# 0    6773.000    6524.000    7276.000    7252.000    7019.000    7073.000
# 1      91.909      91.876      91.754      91.947      92.435      93.101
# 2      32.659      32.649      31.845      31.914      31.628      31.967
# 3      41.799      41.458      42.106      43.101      43.049      39.499
# 4      13.574      13.263      13.975      13.527      13.564      12.908
#
#    22-10-2024  23-10-2024  24-10-2024  25-10-2024  26-10-2024  27-10-2024  \
# 0    6781.000    6146.000    6416.000    6703.000    6458.000    6364.000
# 1      92.273      91.930      92.020      91.646      92.165      91.892
# 2      31.437      30.637      31.064      33.160      33.485      32.250
# 3      41.617      43.133      41.955      40.078      40.843      40.065
# 4      13.745      13.257      12.822      12.974      13.609      12.534
#
#    28-10-2024  29-10-2024  30-10-2024  31-10-2024  01-11-2024  02-11-2024  \
# 0    6324.000    6281.000    6361.000    6103.000    6362.000    7202.000
# 1      78.526      83.936      93.617      94.150      93.964      93.627
# 2      31.977      32.473      31.100      31.187      32.335      32.167
# 3      43.012      42.014      42.485      42.760      42.472      43.719
# 4      14.559      13.297      13.770      14.863      15.457      14.667
#
#    03-11-2024  04-11-2024  05-11-2024  06-11-2024  07-11-2024  08-11-2024  \
# 0    7782.000    6524.000    6172.000    5762.000    5893.000    7219.000
# 1      94.616      94.513      93.908      94.099      93.959      86.452
# 2      30.993      31.252      31.315      31.225      31.335      30.796
# 3      42.089      42.929      41.770      42.014      41.918      43.278
# 4      14.274      13.801      13.423      13.113      14.484      15.863
#
#    09-11-2024  10-11-2024  11-11-2024  12-11-2024  13-11-2024  14-11-2024  \
# 0    7164.000    6652.000    6693.000    6595.000    6708.000    7621.000
# 1      94.486      94.708      93.829      94.162      93.888      94.082
# 2      29.148      30.540      29.650      31.079      30.867      29.400
# 3      46.358      44.349      45.255      44.300      43.776      45.370
# 4      16.768      16.143      14.538      16.006      13.877      14.491
#
#    15-11-2024  16-11-2024  17-11-2024  18-11-2024  19-11-2024  20-11-2024  \
# 0   12057.000    7666.000    7169.000    6736.000    6475.000    6336.000
# 1      95.082      93.739      93.681      93.750      94.008      93.245
# 2      40.387      33.440      31.894      30.530      30.031      30.603
# 3      33.112      44.378      43.627      43.753      44.981      45.311
# 4      11.296      15.113      13.580      14.473      14.720      15.200
#
#    21-11-2024  22-11-2024  23-11-2024  24-11-2024  25-11-2024  26-11-2024
# 0    6775.000    6859.000    7164.000    7375.000    6684.000    6443.000
# 1      90.893      93.687      93.495      93.953      94.195      93.280
# 2      30.416      28.229      29.277      29.932      30.289      28.436
# 3      45.274      46.187      48.328      45.461      44.139      45.075
# 4      15.297      15.437      17.737      15.933      15.677      15.374

# %%
both_calc_df.shape
# Out:
# (34, 93)

# %%
unique_display_names_df_test = df.drop_duplicates(subset='display_names')
unique_display_names_df_test.shape
# Out:
# (181, 111)

# %%
id_columns_both_test = ['create_dt', 'feature_id', 'feature_seq_num', 'metric_sequence_num', 'metric_seqno', 'parent_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names','metric_nature' ]
id_column_both_df_test = unique_display_names_df_test[id_columns_both_test]
#id_column_both_df = id_column_both_df[id_column_both_df['feature_name'].isin(['SMART HELP'])]
id_column_both_df_test.shape
# Out:
# (181, 11)

# %%
# Perform a left merge on 'display_names'
both_df_test =  pd.merge(both_calc_df, id_column_both_df_test, on='display_names', how='inner')
both_df_test.shape
# Out:
# (34, 103)

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 300)      # Show 100 rows
both_df_test.head()
# Out:
#                       display_names operating_system_type metric_id  \
# 0     Reset Modem Start Page Visits                  Both   1000001
# 1             Started Reset Process                  Both   1000002
# 2            Reset Process Complete                  Both   1000003
# 3          Reset Process Incomplete                  Both   1000004
# 4  Reset_Modem Interacted with Chat                  Both   1000005
#
#    29-08-2024  30-08-2024  31-08-2024  01-09-2024  02-09-2024  03-09-2024  \
# 0    7097.000    7306.000    7188.000    7093.000    7314.000    6942.000
# 1      91.306      91.213      91.180      91.696      91.045      90.521
# 2      30.694      30.222      30.607      31.365      30.996      30.442
# 3      42.639      43.923      44.583      43.881      42.874      43.730
# 4      14.120      14.631      15.166      14.699      13.516      14.402
#
#    04-09-2024  05-09-2024  06-09-2024  07-09-2024  08-09-2024  09-09-2024  \
# 0    7552.000    8274.000    7993.000    7568.000    7650.000    7100.000
# 1      90.784      91.624      91.618      90.803      92.902      91.845
# 2      27.334      27.397      28.827      31.257      30.083      31.698
# 3      48.775      48.542      46.306      44.761      43.197      40.853
# 4      15.957      16.858      16.237      14.974      14.169      13.464
#
#    10-09-2024  11-09-2024  12-09-2024  13-09-2024  14-09-2024  15-09-2024  \
# 0    7611.000    6706.000    6428.000    6615.000    7345.000    7793.000
# 1      90.724      88.741      90.884      90.718      91.681      91.428
# 2      30.891      30.331      30.452      31.561      31.155      32.295
# 3      42.911      43.993      42.349      43.076      42.694      42.049
# 4      14.106      15.292      14.772      14.431      14.583      15.663
#
#    16-09-2024  17-09-2024  18-09-2024  19-09-2024  20-09-2024  21-09-2024  \
# 0    6746.000    6558.000    6989.000    6586.000    6798.000    7125.000
# 1      91.625      90.378      91.515      91.193      90.482      90.933
# 2      30.836      30.083      32.051      29.487      31.247      30.159
# 3      43.278      42.416      42.433      44.372      42.156      43.479
# 4      14.658      14.139      13.649      14.602      14.811      14.956
#
#    22-09-2024  23-09-2024  24-09-2024  25-09-2024  26-09-2024  27-09-2024  \
# 0    7310.000    6693.000    6919.000    6793.000    6793.000    6566.000
# 1      92.120      90.811      91.617      91.153      91.874      90.329
# 2      31.868      31.853      28.159      32.187      31.998      31.968
# 3      41.966      41.033      45.149      42.442      42.125      41.662
# 4      13.365      14.182      14.860      14.083      14.164      14.871
#
#    28-09-2024  29-09-2024  30-09-2024  01-10-2024  02-10-2024  03-10-2024  \
# 0    6991.000    7414.000    7974.000    7682.000    6916.000    6714.000
# 1      91.832      92.015      92.300      91.382      90.558      91.346
# 2      30.763      30.944      34.810      31.781      31.646      31.029
# 3      43.988      41.879      38.886      42.293      43.653      43.209
# 4      14.782      13.632      12.785      14.444      15.807      14.137
#
#    04-10-2024  05-10-2024  06-10-2024  07-10-2024  08-10-2024  09-10-2024  \
# 0    6918.000    6884.000    7109.000    6551.000    6429.000    6972.000
# 1      91.472      91.996      91.940      91.589      91.476      91.581
# 2      31.495      31.107      32.375      31.600      29.944      32.545
# 3      41.751      41.986      40.483      41.583      42.969      41.597
# 4      13.812      14.274      13.663      13.933      14.606      14.691
#
#    10-10-2024  11-10-2024  12-10-2024  13-10-2024  14-10-2024  15-10-2024  \
# 0    6265.000    6424.000    6616.000    5860.000    6621.000    6584.000
# 1      92.338      91.469      91.218      91.928      91.270      90.993
# 2      33.258      31.399      32.096      32.987      32.351      31.047
# 3      40.380      41.474      40.199      39.800      42.380      42.864
# 4      13.691      13.870      14.151      13.885      13.917      14.188
#
#    16-10-2024  17-10-2024  18-10-2024  19-10-2024  20-10-2024  21-10-2024  \
# 0    6773.000    6524.000    7276.000    7252.000    7019.000    7073.000
# 1      91.909      91.876      91.754      91.947      92.435      93.101
# 2      32.659      32.649      31.845      31.914      31.628      31.967
# 3      41.799      41.458      42.106      43.101      43.049      39.499
# 4      13.574      13.263      13.975      13.527      13.564      12.908
#
#    22-10-2024  23-10-2024  24-10-2024  25-10-2024  26-10-2024  27-10-2024  \
# 0    6781.000    6146.000    6416.000    6703.000    6458.000    6364.000
# 1      92.273      91.930      92.020      91.646      92.165      91.892
# 2      31.437      30.637      31.064      33.160      33.485      32.250
# 3      41.617      43.133      41.955      40.078      40.843      40.065
# 4      13.745      13.257      12.822      12.974      13.609      12.534
#
#    28-10-2024  29-10-2024  30-10-2024  31-10-2024  01-11-2024  02-11-2024  \
# 0    6324.000    6281.000    6361.000    6103.000    6362.000    7202.000
# 1      78.526      83.936      93.617      94.150      93.964      93.627
# 2      31.977      32.473      31.100      31.187      32.335      32.167
# 3      43.012      42.014      42.485      42.760      42.472      43.719
# 4      14.559      13.297      13.770      14.863      15.457      14.667
#
#    03-11-2024  04-11-2024  05-11-2024  06-11-2024  07-11-2024  08-11-2024  \
# 0    7782.000    6524.000    6172.000    5762.000    5893.000    7219.000
# 1      94.616      94.513      93.908      94.099      93.959      86.452
# 2      30.993      31.252      31.315      31.225      31.335      30.796
# 3      42.089      42.929      41.770      42.014      41.918      43.278
# 4      14.274      13.801      13.423      13.113      14.484      15.863
#
#    09-11-2024  10-11-2024  11-11-2024  12-11-2024  13-11-2024  14-11-2024  \
# 0    7164.000    6652.000    6693.000    6595.000    6708.000    7621.000
# 1      94.486      94.708      93.829      94.162      93.888      94.082
# 2      29.148      30.540      29.650      31.079      30.867      29.400
# 3      46.358      44.349      45.255      44.300      43.776      45.370
# 4      16.768      16.143      14.538      16.006      13.877      14.491
#
#    15-11-2024  16-11-2024  17-11-2024  18-11-2024  19-11-2024  20-11-2024  \
# 0   12057.000    7666.000    7169.000    6736.000    6475.000    6336.000
# 1      95.082      93.739      93.681      93.750      94.008      93.245
# 2      40.387      33.440      31.894      30.530      30.031      30.603
# 3      33.112      44.378      43.627      43.753      44.981      45.311
# 4      11.296      15.113      13.580      14.473      14.720      15.200
#
#    21-11-2024  22-11-2024  23-11-2024  24-11-2024  25-11-2024  26-11-2024  \
# 0    6775.000    6859.000    7164.000    7375.000    6684.000    6443.000
# 1      90.893      93.687      93.495      93.953      94.195      93.280
# 2      30.416      28.229      29.277      29.932      30.289      28.436
# 3      45.274      46.187      48.328      45.461      44.139      45.075
# 4      15.297      15.437      17.737      15.933      15.677      15.374
#
#     create_dt  feature_id feature_seq_num  metric_sequence_num metric_seqno  \
# 0  2025-01-29          11               6                  141            1
# 1  2025-01-29          11               6                  142            2
# 2  2025-01-29          11               6                  143            3
# 3  2025-01-29          11               6                  144            4
# 4  2025-01-29          11               6                  145            5
#
#    parent_id unique_identifier feature_name  \
# 0        NaN                RM  RESET MODEM
# 1      141.0                RM  RESET MODEM
# 2      142.0                RM  RESET MODEM
# 3      142.0                RM  RESET MODEM
# 4      142.0                RM  RESET MODEM
#
#                                       metrics metric_nature
# 0                  DR_Reset Modem - Home Page      Positive
# 1  DR_Reset Modem - Started Rebooting Process      Positive
# 2         DR_Reset Modem - Rebooting Complete      Positive
# 3       DR_Reset Modem - Rebooting Incomplete      Negative
# 4                 DR_Reset Modem - Agent Chat      Negative

# %%
print(list(both_df_test))
# Out:
# ['display_names', 'operating_system_type', 'metric_id', '29-08-2024', '30-08-2024', '31-08-2024', '01-09-2024', '02-09-2024', '03-09-2024', '04-09-2024', '05-09-2024', '06-09-2024', '07-09-2024', '08-09-2024', '09-09-2024', '10-09-2024', '11-09-2024', '12-09-2024', '13-09-2024', '14-09-2024', '15-09-2024', '16-09-2024', '17-09-2024', '18-09-2024', '19-09-2024', '20-09-2024', '21-09-2024', '22-09-2024', '23-09-2024', '24-09-2024', '25-09-2024', '26-09-2024', '27-09-2024', '28-09-2024', '29-09-2024', '30-09-2024', '01-10-2024', '02-10-2024', '03-10-2024', '04-10-2024', '05-10-2024', '06-10-2024', '07-10-2024', '08-10-2024', '09-10-2024', '10-10-2024', '11-10-2024', '12-10-2024', '13-10-2024', '14-10-2024', '15-10-2024', '16-10-2024', '17-10-2024', '18-10-2024', '19-10-2024', '20-10-2024', '21-10-2024', '22-10-2024', '23-10-2024', '24-10-2024', '25-10-2024', '26-10-2024', '27-10-2024', '28-10-2024', '29-10-2024', '30-10-2024', '31-10-2024', '01-11-2024', '02-11-2024', '03-11-2024', '04-11-2024', '05-11-2024', '06-11-2024', '07-11-2024', '08-11-2024', '09-11-2024', '10-11-2024', '11-11-2024', '12-11-2024', '13-11-2024', '14-11-2024', '15-11-2024', '16-11-2024', '17-11-2024', '18-11-2024', '19-11-2024', '20-11-2024', '21-11-2024', '22-11-2024', '23-11-2024', '24-11-2024', '25-11-2024', '26-11-2024', 'create_dt', 'feature_id', 'feature_seq_num', 'metric_sequence_num', 'metric_seqno', 'parent_id', 'unique_identifier', 'feature_name', 'metrics', 'metric_nature']

# %%
both_df_test.shape
# Out:
# (34, 103)

# %%
modifiled_first_table_df = pd.concat([df, both_df_test], ignore_index=True)

# %%
modifiled_first_table_df.shape
# Out:
# (497, 111)

# %%
print(list(modifiled_first_table_df))
# Out:
# ['metrics', 'operating_system_type', '29-08-2024', '30-08-2024', '31-08-2024', '01-09-2024', '02-09-2024', '03-09-2024', '04-09-2024', '05-09-2024', '06-09-2024', '07-09-2024', '08-09-2024', '09-09-2024', '10-09-2024', '11-09-2024', '12-09-2024', '13-09-2024', '14-09-2024', '15-09-2024', '16-09-2024', '17-09-2024', '18-09-2024', '19-09-2024', '20-09-2024', '21-09-2024', '22-09-2024', '23-09-2024', '24-09-2024', '25-09-2024', '26-09-2024', '27-09-2024', '28-09-2024', '29-09-2024', '30-09-2024', '01-10-2024', '02-10-2024', '03-10-2024', '04-10-2024', '05-10-2024', '06-10-2024', '07-10-2024', '08-10-2024', '09-10-2024', '10-10-2024', '11-10-2024', '12-10-2024', '13-10-2024', '14-10-2024', '15-10-2024', '16-10-2024', '17-10-2024', '18-10-2024', '19-10-2024', '20-10-2024', '21-10-2024', '22-10-2024', '23-10-2024', '24-10-2024', '25-10-2024', '26-10-2024', '27-10-2024', '28-10-2024', '29-10-2024', '30-10-2024', '31-10-2024', '01-11-2024', '02-11-2024', '03-11-2024', '04-11-2024', '05-11-2024', '06-11-2024', '07-11-2024', '08-11-2024', '09-11-2024', '10-11-2024', '11-11-2024', '12-11-2024', '13-11-2024', '14-11-2024', '15-11-2024', '16-11-2024', '17-11-2024', '18-11-2024', '19-11-2024', '20-11-2024', '21-11-2024', '22-11-2024', '23-11-2024', '24-11-2024', '25-11-2024', '26-11-2024', 'display_names', 'metric_nature', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'feature_name', 'unique_identifier', 'hierarchy_id', 'parent_id_old', 'metric_id', 'metric_sequence_num', 'metric_seqno', 'level_no', 'feature_id', 'feature_seq_num', 'create_dt', 'parent_id']

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 500)      # Show 100 rows
modifiled_first_table_df = modifiled_first_table_df[['metric_id', 'metrics', 'display_names', 'operating_system_type', 'feature_name', 'unique_identifier', 'metric_nature', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'hierarchy_id', 'parent_id_old', 'metric_sequence_num', 'metric_seqno', 'level_no', 'feature_id', 'feature_seq_num', 'parent_id', 'create_dt']]
modifiled_first_table_df.head()
# Out:
#   metric_id                           metrics                  display_names  \
# 0         1         DR_Visits to Billing Home         Billing Section Visits
# 1         2         DR_Billing Make a Payment                  Make Payments
# 2         3  DR_Client Errors on Make Payment  Client Errors on Payment Page
# 3         4  DR_Server Errors on Make Payment  Server Errors on Payment Page
# 4         5                 DR_Payment Submit                 Payment Submit
#
#   operating_system_type feature_name unique_identifier metric_nature  \
# 0             Apple iOS     BIL LING                BL      Positive
# 1             Apple iOS     BIL LING                BL      Positive
# 2             Apple iOS     BIL LING                BL      Negative
# 3             Apple iOS     BIL LING                BL      Negative
# 4             Apple iOS     BIL LING                BL      Positive
#
#                   level_1         level_2                        level_3  \
# 0  Billing Section Visits            None                           None
# 1                    None   Make Payments                           None
# 2                    None            None  Client Errors on Payment Page
# 3                    None            None  Server Errors on Payment Page
# 4                    None  Payment Submit                           None
#
#   level_4 level_5        hierarchy_id     parent_id_old  metric_sequence_num  \
# 0    None    None      Apple iOS_BL_1              None                    1
# 1    None    None    Apple iOS_BL_1.1    Apple iOS_BL_1                    2
# 2    None    None  Apple iOS_BL_1.1.1  Apple iOS_BL_1.1                    3
# 3    None    None  Apple iOS_BL_1.1.2  Apple iOS_BL_1.1                    4
# 4    None    None    Apple iOS_BL_1.2    Apple iOS_BL_1                    5
#
#   metric_seqno  level_no  feature_id feature_seq_num  parent_id   create_dt
# 0            1       1.0           1               3        NaN  2025-01-29
# 1            2       2.0           1               3        1.0  2025-01-29
# 2            5       3.0           1               3        2.0  2025-01-29
# 3            6       3.0           1               3        2.0  2025-01-29
# 4            3       2.0           1               3        1.0  2025-01-29

# %%
#modifiled_first_table_df.to_csv(r'D:\Healthsore Data\table_1_data_all_featuresnew1.csv', index = False)

# %%
unique_display_names_df = sample_df.drop_duplicates(subset='display_names')
unique_display_names_df.shape
# Out:
# (34, 111)

# %%
id_columns_both = ['create_dt', 'feature_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names', 'parent_id' ]
id_column_both_df = unique_display_names_df[id_columns_both]
#id_column_both_df = id_column_both_df[id_column_both_df['feature_name'].isin(['SMART HELP'])]
id_column_both_df.shape
# Out:
# (34, 7)

# %%
# Perform a left merge on 'display_names'
both_df =  pd.merge(both_calc_df, id_column_both_df, on='display_names', how='inner')
both_df.shape
# Out:
# (34, 99)

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 300)      # Show 100 rows
both_df.head()
# Out:
#                       display_names operating_system_type metric_id  \
# 0     Reset Modem Start Page Visits                  Both   1000001
# 1             Started Reset Process                  Both   1000002
# 2            Reset Process Complete                  Both   1000003
# 3          Reset Process Incomplete                  Both   1000004
# 4  Reset_Modem Interacted with Chat                  Both   1000005
#
#    29-08-2024  30-08-2024  31-08-2024  01-09-2024  02-09-2024  03-09-2024  \
# 0    7097.000    7306.000    7188.000    7093.000    7314.000    6942.000
# 1      91.306      91.213      91.180      91.696      91.045      90.521
# 2      30.694      30.222      30.607      31.365      30.996      30.442
# 3      42.639      43.923      44.583      43.881      42.874      43.730
# 4      14.120      14.631      15.166      14.699      13.516      14.402
#
#    04-09-2024  05-09-2024  06-09-2024  07-09-2024  08-09-2024  09-09-2024  \
# 0    7552.000    8274.000    7993.000    7568.000    7650.000    7100.000
# 1      90.784      91.624      91.618      90.803      92.902      91.845
# 2      27.334      27.397      28.827      31.257      30.083      31.698
# 3      48.775      48.542      46.306      44.761      43.197      40.853
# 4      15.957      16.858      16.237      14.974      14.169      13.464
#
#    10-09-2024  11-09-2024  12-09-2024  13-09-2024  14-09-2024  15-09-2024  \
# 0    7611.000    6706.000    6428.000    6615.000    7345.000    7793.000
# 1      90.724      88.741      90.884      90.718      91.681      91.428
# 2      30.891      30.331      30.452      31.561      31.155      32.295
# 3      42.911      43.993      42.349      43.076      42.694      42.049
# 4      14.106      15.292      14.772      14.431      14.583      15.663
#
#    16-09-2024  17-09-2024  18-09-2024  19-09-2024  20-09-2024  21-09-2024  \
# 0    6746.000    6558.000    6989.000    6586.000    6798.000    7125.000
# 1      91.625      90.378      91.515      91.193      90.482      90.933
# 2      30.836      30.083      32.051      29.487      31.247      30.159
# 3      43.278      42.416      42.433      44.372      42.156      43.479
# 4      14.658      14.139      13.649      14.602      14.811      14.956
#
#    22-09-2024  23-09-2024  24-09-2024  25-09-2024  26-09-2024  27-09-2024  \
# 0    7310.000    6693.000    6919.000    6793.000    6793.000    6566.000
# 1      92.120      90.811      91.617      91.153      91.874      90.329
# 2      31.868      31.853      28.159      32.187      31.998      31.968
# 3      41.966      41.033      45.149      42.442      42.125      41.662
# 4      13.365      14.182      14.860      14.083      14.164      14.871
#
#    28-09-2024  29-09-2024  30-09-2024  01-10-2024  02-10-2024  03-10-2024  \
# 0    6991.000    7414.000    7974.000    7682.000    6916.000    6714.000
# 1      91.832      92.015      92.300      91.382      90.558      91.346
# 2      30.763      30.944      34.810      31.781      31.646      31.029
# 3      43.988      41.879      38.886      42.293      43.653      43.209
# 4      14.782      13.632      12.785      14.444      15.807      14.137
#
#    04-10-2024  05-10-2024  06-10-2024  07-10-2024  08-10-2024  09-10-2024  \
# 0    6918.000    6884.000    7109.000    6551.000    6429.000    6972.000
# 1      91.472      91.996      91.940      91.589      91.476      91.581
# 2      31.495      31.107      32.375      31.600      29.944      32.545
# 3      41.751      41.986      40.483      41.583      42.969      41.597
# 4      13.812      14.274      13.663      13.933      14.606      14.691
#
#    10-10-2024  11-10-2024  12-10-2024  13-10-2024  14-10-2024  15-10-2024  \
# 0    6265.000    6424.000    6616.000    5860.000    6621.000    6584.000
# 1      92.338      91.469      91.218      91.928      91.270      90.993
# 2      33.258      31.399      32.096      32.987      32.351      31.047
# 3      40.380      41.474      40.199      39.800      42.380      42.864
# 4      13.691      13.870      14.151      13.885      13.917      14.188
#
#    16-10-2024  17-10-2024  18-10-2024  19-10-2024  20-10-2024  21-10-2024  \
# 0    6773.000    6524.000    7276.000    7252.000    7019.000    7073.000
# 1      91.909      91.876      91.754      91.947      92.435      93.101
# 2      32.659      32.649      31.845      31.914      31.628      31.967
# 3      41.799      41.458      42.106      43.101      43.049      39.499
# 4      13.574      13.263      13.975      13.527      13.564      12.908
#
#    22-10-2024  23-10-2024  24-10-2024  25-10-2024  26-10-2024  27-10-2024  \
# 0    6781.000    6146.000    6416.000    6703.000    6458.000    6364.000
# 1      92.273      91.930      92.020      91.646      92.165      91.892
# 2      31.437      30.637      31.064      33.160      33.485      32.250
# 3      41.617      43.133      41.955      40.078      40.843      40.065
# 4      13.745      13.257      12.822      12.974      13.609      12.534
#
#    28-10-2024  29-10-2024  30-10-2024  31-10-2024  01-11-2024  02-11-2024  \
# 0    6324.000    6281.000    6361.000    6103.000    6362.000    7202.000
# 1      78.526      83.936      93.617      94.150      93.964      93.627
# 2      31.977      32.473      31.100      31.187      32.335      32.167
# 3      43.012      42.014      42.485      42.760      42.472      43.719
# 4      14.559      13.297      13.770      14.863      15.457      14.667
#
#    03-11-2024  04-11-2024  05-11-2024  06-11-2024  07-11-2024  08-11-2024  \
# 0    7782.000    6524.000    6172.000    5762.000    5893.000    7219.000
# 1      94.616      94.513      93.908      94.099      93.959      86.452
# 2      30.993      31.252      31.315      31.225      31.335      30.796
# 3      42.089      42.929      41.770      42.014      41.918      43.278
# 4      14.274      13.801      13.423      13.113      14.484      15.863
#
#    09-11-2024  10-11-2024  11-11-2024  12-11-2024  13-11-2024  14-11-2024  \
# 0    7164.000    6652.000    6693.000    6595.000    6708.000    7621.000
# 1      94.486      94.708      93.829      94.162      93.888      94.082
# 2      29.148      30.540      29.650      31.079      30.867      29.400
# 3      46.358      44.349      45.255      44.300      43.776      45.370
# 4      16.768      16.143      14.538      16.006      13.877      14.491
#
#    15-11-2024  16-11-2024  17-11-2024  18-11-2024  19-11-2024  20-11-2024  \
# 0   12057.000    7666.000    7169.000    6736.000    6475.000    6336.000
# 1      95.082      93.739      93.681      93.750      94.008      93.245
# 2      40.387      33.440      31.894      30.530      30.031      30.603
# 3      33.112      44.378      43.627      43.753      44.981      45.311
# 4      11.296      15.113      13.580      14.473      14.720      15.200
#
#    21-11-2024  22-11-2024  23-11-2024  24-11-2024  25-11-2024  26-11-2024  \
# 0    6775.000    6859.000    7164.000    7375.000    6684.000    6443.000
# 1      90.893      93.687      93.495      93.953      94.195      93.280
# 2      30.416      28.229      29.277      29.932      30.289      28.436
# 3      45.274      46.187      48.328      45.461      44.139      45.075
# 4      15.297      15.437      17.737      15.933      15.677      15.374
#
#     create_dt  feature_id unique_identifier feature_name  \
# 0  2025-01-28          11                RM  RESET MODEM
# 1  2025-01-28          11                RM  RESET MODEM
# 2  2025-01-28          11                RM  RESET MODEM
# 3  2025-01-28          11                RM  RESET MODEM
# 4  2025-01-28          11                RM  RESET MODEM
#
#                                       metrics  parent_id
# 0                  DR_Reset Modem - Home Page        NaN
# 1  DR_Reset Modem - Started Rebooting Process      141.0
# 2         DR_Reset Modem - Rebooting Complete      142.0
# 3       DR_Reset Modem - Rebooting Incomplete      142.0
# 4                 DR_Reset Modem - Agent Chat      142.0

# %%
third_table_df = pd.concat([percent_df, both_df], ignore_index=True)

# %%
third_table_df.shape
# Out:
# (102, 104)

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 200)      # Show 100 rows
third_table_df.head(5)
# Out:
#     create_dt metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 0  2025-01-28       141          11               6                141.0
# 1  2025-01-28       142          11               6                142.0
# 2  2025-01-28       143          11               6                143.0
# 3  2025-01-28       144          11               6                144.0
# 4  2025-01-28       145          11               6                145.0
#
#    metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 0           1.0       1.0        NaN                RM  RESET MODEM
# 1           2.0       2.0      141.0                RM  RESET MODEM
# 2           3.0       3.0      142.0                RM  RESET MODEM
# 3           4.0       3.0      142.0                RM  RESET MODEM
# 4           5.0       3.0      142.0                RM  RESET MODEM
#
#                                       metrics  \
# 0                  DR_Reset Modem - Home Page
# 1  DR_Reset Modem - Started Rebooting Process
# 2         DR_Reset Modem - Rebooting Complete
# 3       DR_Reset Modem - Rebooting Incomplete
# 4                 DR_Reset Modem - Agent Chat
#
#                       display_names operating_system_type metric_nature  \
# 0     Reset Modem Start Page Visits             Apple iOS      Positive
# 1             Started Reset Process             Apple iOS      Positive
# 2            Reset Process Complete             Apple iOS      Positive
# 3          Reset Process Incomplete             Apple iOS      Negative
# 4  Reset_Modem Interacted with Chat             Apple iOS      Negative
#
#   29-08-2024 30-08-2024 31-08-2024 01-09-2024 02-09-2024 03-09-2024  \
# 0     5306.0     5499.0     5415.0     5353.0     5588.0     5238.0
# 1     91.199     91.071     91.043     91.612     90.909      90.34
# 2     30.544     30.551     31.136     31.852      31.28     30.959
# 3     45.485     46.745     47.221     46.635     46.024     46.048
# 4     14.569     14.736     15.538     15.314     13.701     14.708
#
#   04-09-2024 05-09-2024 06-09-2024 07-09-2024 08-09-2024 09-09-2024  \
# 0     5630.0     6204.0     6118.0     5738.0     5762.0     5322.0
# 1     90.515      91.86     91.533     90.519     92.555     91.714
# 2     27.924     27.479     28.964     31.498     30.677     32.207
# 3     51.609      51.43     49.089     47.728     45.753     43.536
# 4     16.405     16.898     16.446     15.325     14.682     14.116
#
#   10-09-2024 11-09-2024 12-09-2024 13-09-2024 14-09-2024 15-09-2024  \
# 0     5746.0     4950.0     4861.0     4955.0     5519.0     5737.0
# 1     90.637     88.909     90.866     90.817     91.393     91.424
# 2      31.26     30.834     31.175     31.933     31.761     32.698
# 3     45.584     47.217     44.419       45.6     45.341     45.548
# 4      14.67     15.883     15.033     14.956     15.186     15.844
#
#   16-09-2024 17-09-2024 18-09-2024 19-09-2024 20-09-2024 21-09-2024  \
# 0     5066.0     4975.0     5269.0     4883.0     5107.0     5354.0
# 1     91.453     90.231     91.744     91.214     90.347     91.016
# 2     31.815      30.14     32.458     29.906     31.491     30.371
# 3     45.651     45.556     45.201     47.081     44.928     46.029
# 4     15.023     14.903     13.984     15.177     15.301      15.37
#
#   22-09-2024 23-09-2024 24-09-2024 25-09-2024 26-09-2024 27-09-2024  \
# 0     5501.0     4933.0     5254.0     5066.0     5078.0     4948.0
# 1     92.129      90.31     91.663     91.196     91.729      90.36
# 2     32.261     32.727     28.135      33.29     32.675     32.386
# 3     44.988     43.434     48.007     44.762     45.019     44.241
# 4     13.418     14.658     15.386     14.264     14.641     15.522
#
#   28-09-2024 29-09-2024 30-09-2024 01-10-2024 02-10-2024 03-10-2024  \
# 0     5244.0     5526.0     5932.0     5742.0     5079.0     4916.0
# 1     91.686     91.947     92.481     91.414      90.49     90.989
# 2     31.468     31.982     35.709     32.559      32.05     31.612
# 3     46.152     44.302     42.417     44.447     46.584     45.674
# 4     14.809     13.875     13.361     15.012     16.057     14.397
#
#   04-10-2024 05-10-2024 06-10-2024 07-10-2024 08-10-2024 09-10-2024  \
# 0     5167.0     5095.0     5282.0     4811.0     4788.0     5203.0
# 1     90.981     91.894      91.84     91.561     91.332     91.928
# 2     31.632     31.269     32.839     32.213     30.848     32.657
# 3     44.161     45.237     43.352     44.926     44.935     43.947
# 4     13.997     14.801     13.523     14.665     14.475     14.907
#
#   10-10-2024 11-10-2024 12-10-2024 13-10-2024 14-10-2024 15-10-2024  \
# 0     4647.0     4820.0     4883.0     4430.0     4915.0     4860.0
# 1     92.232     91.369      91.03      91.67     91.129     90.679
# 2     34.064     32.016     32.373     33.021     33.512     31.427
# 3      43.07     43.937      42.97     42.305     44.787     45.791
# 4     14.139     14.078     14.533     14.307     13.954     14.636
#
#   16-10-2024 17-10-2024 18-10-2024 19-10-2024 20-10-2024 21-10-2024  \
# 0     5033.0     4824.0     5393.0     5422.0     5324.0     4951.0
# 1     92.271     91.915     91.749     92.088     92.825     93.133
# 2     33.226     33.175     32.235     32.606     31.971     32.661
# 3      43.82     43.054     44.665     45.143     45.467      43.83
# 4     13.695     13.216     14.147     13.739     13.901     13.858
#
#   22-10-2024 23-10-2024 24-10-2024 25-10-2024 26-10-2024 27-10-2024  \
# 0     4931.0     4573.0     4797.0     4963.0     4711.0     4791.0
# 1     92.213     91.494     91.912     91.416     92.061     91.547
# 2     32.219     31.286     32.184     33.767     33.825     33.174
# 3     44.095      46.08     43.683     42.848      43.21     42.316
# 4     13.965     13.432     12.724     13.599     13.858     12.472
#
#   28-10-2024 29-10-2024 30-10-2024 31-10-2024 01-11-2024 02-11-2024  \
# 0     4715.0     4702.0     4636.0     4508.0     4668.0     5393.0
# 1     78.876     84.347     93.723     94.476     93.766     93.621
# 2     32.267     32.703     31.899     31.251     32.122     32.957
# 3     46.034     44.831     44.649     45.809     45.693     46.782
# 4     14.547     13.364     13.763     15.497     16.198     15.052
#
#   03-11-2024 04-11-2024 05-11-2024 06-11-2024 07-11-2024 08-11-2024  \
# 0     5706.0     4926.0     4612.0     4219.0     4317.0     5308.0
# 1     94.532     94.884     93.799     94.098     93.931     86.907
# 2     31.127     31.579     32.247     32.317     32.281     31.606
# 3     44.587     45.336     43.828      44.71      44.76     46.087
# 4     14.739     14.292     12.968     13.451     14.846     16.367
#
#   09-11-2024 10-11-2024 11-11-2024 12-11-2024 13-11-2024 14-11-2024  \
# 0     5262.0     5030.0     4957.0     4926.0     4920.0     5601.0
# 1     94.584     94.513     93.706     94.316     93.862     94.072
# 2     29.918     30.164     30.549     30.758     31.247     29.398
# 3     48.805     47.497     47.578     47.611     46.275     47.865
# 4     16.958     16.428     14.704     16.573     14.249     14.785
#
#   15-11-2024 16-11-2024 17-11-2024 18-11-2024 19-11-2024 20-11-2024  \
# 0     8941.0     5652.0     5370.0     4983.0     4760.0     4617.0
# 1     95.068     93.825     93.762     93.859     93.676     93.199
# 2       42.0     34.339     32.771     31.858     30.433     31.861
# 3     36.129     46.577     45.998     46.547     47.701     47.339
# 4     11.306     15.199     13.684     14.945     14.981     14.827
#
#   21-11-2024 22-11-2024 23-11-2024 24-11-2024 25-11-2024 26-11-2024
# 0     4981.0     5001.0     5260.0     5455.0     4976.0     4739.0
# 1     91.207     93.461     93.669     94.042     94.293     93.395
# 2     30.883     29.397     29.957     29.708     30.754     28.513
# 3     47.436     47.689     49.645     48.363     46.377     47.402
# 4     14.704     14.848     17.901     16.043     15.644     15.612

# %%
#third_table_df.to_csv(r'D:\Healthsore Data\table_3_data_3_features.csv', index = False)

# %%
third_table_melted_df = pd.melt(third_table_df, id_vars=id_columns, 
                     value_vars=date_columns, 
                     var_name='Date', 
                     value_name='Value')

# %%
third_table_melted_df.shape
# Out:
# (9180, 16)

# %%
third_table_melted_df.columns
# Out:
# Index(['create_dt', 'metric_id', 'feature_id', 'feature_seq_num',
#        'metric_sequence_num', 'metric_seqno', 'level_no', 'parent_id',
#        'unique_identifier', 'feature_name', 'metrics', 'display_names',
#        'operating_system_type', 'metric_nature', 'Date', 'Value'],
#       dtype='object')

# %%
third_table_final_df = third_table_melted_df[['create_dt', 'metric_id', 'feature_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names', 'operating_system_type', 'Date', 'Value']]

# %%
third_table_final_df.head()
# Out:
#     create_dt metric_id  feature_id unique_identifier feature_name  \
# 0  2025-01-28       141          11                RM  RESET MODEM
# 1  2025-01-28       142          11                RM  RESET MODEM
# 2  2025-01-28       143          11                RM  RESET MODEM
# 3  2025-01-28       144          11                RM  RESET MODEM
# 4  2025-01-28       145          11                RM  RESET MODEM
#
#                                       metrics  \
# 0                  DR_Reset Modem - Home Page
# 1  DR_Reset Modem - Started Rebooting Process
# 2         DR_Reset Modem - Rebooting Complete
# 3       DR_Reset Modem - Rebooting Incomplete
# 4                 DR_Reset Modem - Agent Chat
#
#                       display_names operating_system_type        Date   Value
# 0     Reset Modem Start Page Visits             Apple iOS  29-08-2024  5306.0
# 1             Started Reset Process             Apple iOS  29-08-2024  91.199
# 2            Reset Process Complete             Apple iOS  29-08-2024  30.544
# 3          Reset Process Incomplete             Apple iOS  29-08-2024  45.485
# 4  Reset_Modem Interacted with Chat             Apple iOS  29-08-2024  14.569

# %%
third_table_final_df.shape
# Out:
# (9180, 10)

# %%
#third_table_final_df.to_csv(r'D:\Healthsore Data\table_3_data_3_features_athenanew.csv', index = False)

# %%
third_table_melted_df.dtypes
# Out:
# create_dt                 object
# metric_id                 object
# feature_id                 int64
# feature_seq_num           object
# metric_sequence_num      float64
# metric_seqno             float64
# level_no                 float64
# parent_id                float64
# unique_identifier         object
# feature_name              object
# metrics                   object
# display_names             object
# operating_system_type     object
# metric_nature             object
# Date                      object
# Value                     object
# dtype: object

# %%
# Convert 'create_dt' and 'Date' to datetime
third_table_melted_df['create_dt'] = pd.to_datetime(third_table_melted_df['create_dt'], errors='coerce')
third_table_melted_df['Date'] = pd.to_datetime(third_table_melted_df['Date'], errors='coerce')

# Convert 'feature_id', 'metric_sequence_num', 'level_no', 'parent_id' to integers
third_table_melted_df['feature_id'] = third_table_melted_df['feature_id'].astype('Int64')  # 'Int64' to handle missing values (NaN)
third_table_melted_df['feature_seq_num'] = third_table_melted_df['feature_seq_num'].astype('Int64')
third_table_melted_df['metric_sequence_num'] = third_table_melted_df['metric_sequence_num'].astype('Int64')
third_table_melted_df['metric_seqno'] = third_table_melted_df['metric_seqno'].astype('Int64')
third_table_melted_df['level_no'] = third_table_melted_df['level_no'].astype('Int64')
third_table_melted_df['parent_id'] = third_table_melted_df['parent_id'].astype('Int64')
#third_table_melted_df['metric_id'] = third_table_melted_df['metric_id'].astype('Int64')

# Convert 'metric_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names', 'operating_system_type' to strings
third_table_melted_df['metric_id'] = third_table_melted_df['metric_id'].astype(str)
third_table_melted_df['unique_identifier'] = third_table_melted_df['unique_identifier'].astype(str)
third_table_melted_df['feature_name'] = third_table_melted_df['feature_name'].astype(str)
third_table_melted_df['metrics'] = third_table_melted_df['metrics'].astype(str)
third_table_melted_df['display_names'] = third_table_melted_df['display_names'].astype(str)
third_table_melted_df['operating_system_type'] = third_table_melted_df['operating_system_type'].astype(str)
third_table_melted_df['metric_nature'] = third_table_melted_df['metric_nature'].astype(str)

# Convert 'Value' to float
third_table_melted_df['Value'] = pd.to_numeric(third_table_melted_df['Value'], errors='coerce')

# %%
third_table_melted_df.dtypes
# Out:
# create_dt                datetime64[ns]
# metric_id                        object
# feature_id                        Int64
# feature_seq_num                   Int64
# metric_sequence_num               Int64
# metric_seqno                      Int64
# level_no                          Int64
# parent_id                         Int64
# unique_identifier                object
# feature_name                     object
# metrics                          object
# display_names                    object
# operating_system_type            object
# metric_nature                    object
# Date                     datetime64[ns]
# Value                           float64
# dtype: object

# %%
#Calculate 1st and 3rd quartiles
quartiles = third_table_melted_df.groupby(['operating_system_type', 'display_names'])['Value'].quantile([0.25, 0.75]).unstack()
quartiles.reset_index(inplace=True)
quartiles.columns.name = None  # Remove the index name
quartiles.columns = ['operating_system_type', 'display_names', '1st Quartile', '3rd Quartile']
#Calculate IQR
quartiles['IQR'] = quartiles['3rd Quartile'] - quartiles['1st Quartile']

# %%
quartiles.shape
# Out:
# (102, 5)

# %%
quartiles_iqr_df = pd.merge(third_table_df, quartiles, on=['display_names', 'operating_system_type'], how='outer')

# %%
quartiles_iqr_df.shape
# Out:
# (102, 107)

# %%
pd.set_option('display.max_columns', None)  # Show all columns 
pd.set_option('display.max_rows', 200)      # Show 100 rows 
quartiles_iqr_df.head()
# Out:
#     create_dt metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 0  2025-01-28       186          15               5                186.0
# 1  2025-01-28  10000020          15             NaN                  NaN
# 2  2025-01-28       420          15               5                184.0
# 3  2025-01-28       187          15               5                187.0
# 4  2025-01-28  10000021          15             NaN                  NaN
#
#    metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 0           4.0       4.0      185.0                SH   SMART HELP
# 1           NaN       NaN      185.0                SH   SMART HELP
# 2          22.0       4.0      419.0                SH   SMART HELP
# 3           5.0       4.0      185.0                SH   SMART HELP
# 4           NaN       NaN      185.0                SH   SMART HELP
#
#                               metrics                     display_names  \
# 0       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 1       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 2       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 3  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
# 4  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
#
#   operating_system_type metric_nature 29-08-2024 30-08-2024 31-08-2024  \
# 0             Apple iOS      Negative     78.947       84.0     80.909
# 1                  Both           NaN     78.689     80.556     80.392
# 2        Google Android      Negative     78.261     72.727      79.07
# 3             Apple iOS      Negative     14.474       10.0     11.818
# 4                  Both           NaN     13.115     11.111     13.725
#
#   01-09-2024 02-09-2024 03-09-2024 04-09-2024 05-09-2024 06-09-2024  \
# 0     68.235     78.049     74.118     73.786     77.622     81.053
# 1     68.462     76.923      70.29     74.497     76.682     79.221
# 2     68.889     74.286     64.151     76.087       75.0     76.271
# 3     18.824     15.854     15.294     16.505     11.888     10.526
# 4     18.462     17.094     21.739     16.779     13.901     11.688
#
#   07-09-2024 08-09-2024 09-09-2024 10-09-2024 11-09-2024 12-09-2024  \
# 0     77.228     75.455     83.784     88.095     72.727     85.321
# 1     71.014     74.405     75.214     83.871     76.271     84.516
# 2     54.054     72.414     60.465       75.0     82.927     82.609
# 3     12.871     16.364      8.108      7.143     19.481     11.009
# 4     16.667     19.048      14.53     12.903     14.407     12.258
#
#   13-09-2024 14-09-2024 15-09-2024 16-09-2024 17-09-2024 18-09-2024  \
# 0     82.653     80.435     89.046     60.099      8.108      8.333
# 1     83.099     77.419     90.612     60.912       11.0     10.345
# 2     84.091      68.75     92.754       62.5     19.231     14.815
# 3     14.286      9.783      9.541     21.182      1.351        0.0
# 4     11.972     12.903      7.755     23.127        1.0        0.0
#
#   19-09-2024 20-09-2024 21-09-2024 22-09-2024 23-09-2024 24-09-2024  \
# 0      7.955      6.667      4.615      7.595     10.938     16.667
# 1      7.965      6.542      7.407       8.13      9.195     16.176
# 2        8.0       6.25     11.628      9.091      4.348     14.706
# 3      2.273      1.333        0.0        0.0        0.0        0.0
# 4       1.77      0.935        0.0        0.0      1.149        0.0
#
#   25-09-2024 26-09-2024 27-09-2024 28-09-2024 29-09-2024 30-09-2024  \
# 0      9.091     11.628     11.765     10.145      7.921     10.753
# 1      9.804      11.29     14.286     11.828      8.955       12.5
# 2     11.111     10.526     18.919     16.667     12.121     18.519
# 3      1.515      1.163        0.0        0.0        0.0        0.0
# 4       0.98      0.806        0.0        0.0        0.0        0.0
#
#   01-10-2024 02-10-2024 03-10-2024 04-10-2024 05-10-2024 06-10-2024  \
# 0      8.974     10.667     63.636     75.862     75.789     73.958
# 1       8.85      8.612     65.254     77.344     69.014     73.485
# 2      8.571       3.39     68.293     80.488     55.319     72.222
# 3        0.0        0.0      10.39      9.195      9.474     16.667
# 4        0.0        0.0      8.475     10.156     15.493     18.182
#
#   07-10-2024 08-10-2024 09-10-2024 10-10-2024 11-10-2024 12-10-2024  \
# 0     75.309     69.663     68.085     74.667     75.714     78.824
# 1       75.0     66.942     65.854     72.727     70.707     74.167
# 2     74.074     59.375     58.621     66.667     58.621     62.857
# 3     18.519      15.73      13.83     13.333     11.429     11.765
# 4     18.519     16.529      16.26     15.152     15.152       17.5
#
#   13-10-2024 14-10-2024 15-10-2024 16-10-2024 17-10-2024 18-10-2024  \
# 0     60.317     66.667     63.725     57.955     57.647     58.889
# 1     61.053     66.154     65.909     57.895     58.586     62.295
# 2       62.5     64.706     73.333     57.692     64.286     71.875
# 3     22.222     17.708     22.549     28.409     22.353     22.222
# 4     22.105     15.385     22.727     26.316     25.253     21.311
#
#   19-10-2024 20-10-2024 21-10-2024 22-10-2024 23-10-2024 24-10-2024  \
# 0     54.455     62.195     47.561     61.765     58.095     63.014
# 1     55.072     61.947     55.085     66.412     58.451     64.356
# 2     56.757      61.29     72.222     82.759     59.459     67.857
# 3     37.624     23.171     26.829     26.471     27.619     26.027
# 4     34.058     24.779     21.186     25.191     26.761     27.723
#
#   25-10-2024 26-10-2024 27-10-2024 28-10-2024 29-10-2024 30-10-2024  \
# 0     54.545     59.211      56.79     65.116      51.25     55.102
# 1     54.762     57.983     58.182     64.516     49.495     57.246
# 2     55.263     55.814     62.069     63.158     42.105       62.5
# 3     26.136     22.368     24.691      29.07       25.0     22.449
# 4     30.159      24.37     24.545     27.419     27.273     22.464
#
#   31-10-2024 01-11-2024 02-11-2024 03-11-2024 04-11-2024 05-11-2024  \
# 0     54.545     71.429     67.442     65.854     63.095     54.412
# 1      56.25     71.329     66.387     67.816       64.8     59.574
# 2       60.0     71.053     63.636     72.549     68.293     73.077
# 3     25.974     17.143     24.419     20.325     27.381     27.941
# 4     23.214      19.58      24.37     21.264       22.4     23.404
#
#   06-11-2024 07-11-2024 08-11-2024 09-11-2024 10-11-2024 11-11-2024  \
# 0     66.667       60.0     53.846     57.895     46.479     53.086
# 1     68.687     54.701     55.455     57.522     47.423     55.446
# 2     73.333     40.625     59.375     56.757       50.0       65.0
# 3     21.739     23.529     17.949       25.0     33.803     28.395
# 4     19.192     24.786       20.0     25.664     34.021     27.723
#
#   12-11-2024 13-11-2024 14-11-2024 15-11-2024 16-11-2024 17-11-2024  \
# 0     65.556     56.164     63.529       70.0       60.0     54.545
# 1     67.391     57.009     61.789     65.254     57.895     53.153
# 2     70.833     58.824     57.895     55.263     53.488       50.0
# 3       20.0     27.397     17.647       20.0     23.333     23.377
# 4     18.841     24.299     17.886     18.644     21.805     27.928
#
#   18-11-2024 19-11-2024 20-11-2024 21-11-2024 22-11-2024 23-11-2024  \
# 0     55.357     51.351     59.459       55.0     56.962     56.818
# 1     52.941     49.541     55.446     56.911     57.895     48.701
# 2     48.276     45.714     44.444     60.465       60.0     37.879
# 3     26.786     22.973     25.676       17.5     20.253     22.727
# 4     29.412     26.606     26.733     21.951     21.053     25.974
#
#   24-11-2024 25-11-2024 26-11-2024  1st Quartile  3rd Quartile       IQR
# 0     62.295     66.142     66.216      54.42275      73.52125  19.09850
# 1     65.318     61.053     64.151      54.71625      70.60275  15.88650
# 2     72.549     50.794     59.375      50.00000      72.13525  22.13525
# 3     14.754     16.535     21.622      10.09750      23.29250  13.19500
# 4     13.295     18.947     23.585      12.41925      24.12050  11.70125

# %%
#quartiles_iqr_df_sample = quartiles_iqr_df[quartiles_iqr_df['feature_name'].isin(['SMART HELP'])]

# %%
#quartiles_iqr_df_sample.shape

# %%
def calculate_upper_lower(df, parent_column='parent_id'):
    # Ensure parent_column is present in the dataframe
    if parent_column not in df.columns:
        raise ValueError(f"{parent_column} not found in the dataframe")
    
    # Find the display_names where parent_id is null for 'Apple iOS'
    apple_ios_null_parent = df[(df['operating_system_type'] == 'Apple iOS') & 
                               (pd.isna(df[parent_column]) | df[parent_column] == '')]['display_names'].unique()

    # Define the function to apply to each row
    def calculate_row(row):
        # Check for the operating_system_type and display_names logic
        if row['operating_system_type'] == 'Both':
            if row['display_names'] in apple_ios_null_parent:
                # Apply 1.25 multiplier if display_names matches those with null parent_id in 'Apple iOS'
                upper = row['3rd Quartile'] + (1.25 * row['IQR'])
                lower = row['1st Quartile'] - (1.25 * row['IQR'])
            else:
                # Apply 0.75 multiplier for other rows
                upper = row['3rd Quartile'] + (0.75 * row['IQR'])
                lower = row['1st Quartile'] - (0.75 * row['IQR'])
        else:
            # For other operating system types, apply the 0.75 logic by default
            upper = row['3rd Quartile'] + (0.75 * row['IQR'])
            lower = row['1st Quartile'] - (0.75 * row['IQR'])

        return pd.Series({'Upper': upper, 'Lower': lower})
    
    # Apply the function row by row
    df[['Upper', 'Lower']] = df.apply(calculate_row, axis=1)

    # Round the Upper column to 1 decimal place
    df['Upper'] = df['Upper'].round(1)

    return df

# %%
# Assuming quartiles_iqr_df is already defined
upper_lower_df = calculate_upper_lower(quartiles_iqr_df) 
upper_lower_df = upper_lower_df[['display_names', 'operating_system_type', '1st Quartile', '3rd Quartile', 'IQR', 'Upper', 'Lower']] 
pd.set_option('display.max_columns', None)  # Show all columns 
pd.set_option('display.max_rows', 100)      # Show 100 rows 
upper_lower_df.head(100)
# Out:
#                                 display_names operating_system_type  \
# 0                 1st common reason (Unknown)             Apple iOS
# 1                 1st common reason (Unknown)                  Both
# 2                 1st common reason (Unknown)        Google Android
# 3            2nd common reason (Disconnected)             Apple iOS
# 4            2nd common reason (Disconnected)                  Both
# 5            2nd common reason (Disconnected)        Google Android
# 6      3rd common reason (Incomplete Install)             Apple iOS
# 7      3rd common reason (Incomplete Install)                  Both
# 8      3rd common reason (Incomplete Install)        Google Android
# 9           Clicked Billing & Account Support             Apple iOS
# 10          Clicked Billing & Account Support                  Both
# 11          Clicked Billing & Account Support        Google Android
# 12                   Clicked Homelife Support             Apple iOS
# 13                   Clicked Homelife Support                  Both
# 14                   Clicked Homelife Support        Google Android
# 15                   Clicked Internet Support             Apple iOS
# 16                   Clicked Internet Support                  Both
# 17                   Clicked Internet Support        Google Android
# 18                         Clicked TV Support             Apple iOS
# 19                         Clicked TV Support                  Both
# 20                         Clicked TV Support        Google Android
# 21                         Connect with Agent             Apple iOS
# 22                         Connect with Agent                  Both
# 23                         Connect with Agent        Google Android
# 24                                 DMCA Error             Apple iOS
# 25                                 DMCA Error                  Both
# 26                                 DMCA Error        Google Android
# 27                        Devices Page Visits             Apple iOS
# 28                        Devices Page Visits                  Both
# 29                        Devices Page Visits        Google Android
# 30                        Did a Device Reboot             Apple iOS
# 31                        Did a Device Reboot                  Both
# 32                        Did a Device Reboot        Google Android
# 33                               Error Outage             Apple iOS
# 34                               Error Outage                  Both
# 35                               Error Outage        Google Android
# 36                              Non Pay Error             Apple iOS
# 37                              Non Pay Error                  Both
# 38                              Non Pay Error        Google Android
# 39              Reset Modem Start Page Visits             Apple iOS
# 40              Reset Modem Start Page Visits                  Both
# 41              Reset Modem Start Page Visits        Google Android
# 42                     Reset Process Complete             Apple iOS
# 43                     Reset Process Complete                  Both
# 44                     Reset Process Complete        Google Android
# 45                   Reset Process Incomplete             Apple iOS
# 46                   Reset Process Incomplete                  Both
# 47                   Reset Process Incomplete        Google Android
# 48             Reset TV Box Start Page Visits             Apple iOS
# 49             Reset TV Box Start Page Visits                  Both
# 50             Reset TV Box Start Page Visits        Google Android
# 51           Reset_Modem Interacted with Chat             Apple iOS
# 52           Reset_Modem Interacted with Chat                  Both
# 53           Reset_Modem Interacted with Chat        Google Android
# 54                        Reset_TV DMCA Error             Apple iOS
# 55                        Reset_TV DMCA Error                  Both
# 56                        Reset_TV DMCA Error        Google Android
# 57                      Reset_TV Error Outage             Apple iOS
# 58                      Reset_TV Error Outage                  Both
# 59                      Reset_TV Error Outage        Google Android
# 60              Reset_TV Interacted with Chat             Apple iOS
# 61              Reset_TV Interacted with Chat                  Both
# 62              Reset_TV Interacted with Chat        Google Android
# 63                     Reset_TV Non Pay Error             Apple iOS
# 64                     Reset_TV Non Pay Error                  Both
# 65                     Reset_TV Non Pay Error        Google Android
# 66                  Reset_TV Process Complete             Apple iOS
# 67                  Reset_TV Process Complete                  Both
# 68                  Reset_TV Process Complete        Google Android
# 69                Reset_TV Process Incomplete             Apple iOS
# 70                Reset_TV Process Incomplete                  Both
# 71                Reset_TV Process Incomplete        Google Android
# 72             Reset_TV Started Reset Process             Apple iOS
# 73             Reset_TV Started Reset Process                  Both
# 74             Reset_TV Started Reset Process        Google Android
# 75                               Saw a Result             Apple iOS
# 76                               Saw a Result                  Both
# 77                               Saw a Result        Google Android
# 78                              Schedule Tech             Apple iOS
# 79                              Schedule Tech                  Both
# 80                              Schedule Tech        Google Android
# 81                   Smarthelp Reset Complete             Apple iOS
# 82                   Smarthelp Reset Complete                  Both
# 83                   Smarthelp Reset Complete        Google Android
# 84             Smarthelp_Interacted with Chat             Apple iOS
# 85             Smarthelp_Interacted with Chat                  Both
# 86             Smarthelp_Interacted with Chat        Google Android
# 87         Smarthelp_P&P Interacted with Chat             Apple iOS
# 88         Smarthelp_P&P Interacted with Chat                  Both
# 89         Smarthelp_P&P Interacted with Chat        Google Android
# 90                Started P&P troubleshooting             Apple iOS
# 91                Started P&P troubleshooting                  Both
# 92                Started P&P troubleshooting        Google Android
# 93     Started Proactive and Preventive (P&P)             Apple iOS
# 94     Started Proactive and Preventive (P&P)                  Both
# 95     Started Proactive and Preventive (P&P)        Google Android
# 96                      Started Reset Process             Apple iOS
# 97                      Started Reset Process                  Both
# 98                      Started Reset Process        Google Android
# 99  Started Troubleshooting (Solution Center)             Apple iOS
#
#     1st Quartile  3rd Quartile         IQR    Upper        Lower
# 0       54.42275      73.52125    19.09850     87.8    40.098875
# 1       54.71625      70.60275    15.88650     82.5    42.801375
# 2       50.00000      72.13525    22.13525     88.7    33.398562
# 3       10.09750      23.29250    13.19500     33.2     0.201250
# 4       12.41925      24.12050    11.70125     32.9     3.643313
# 5       10.07050      25.43575    15.36525     37.0    -1.453437
# 6        1.61800       6.64500     5.02700     10.4    -2.152250
# 7        2.53175       7.18900     4.65725     10.7    -0.961188
# 8        2.17400       9.66075     7.48675     15.3    -3.441063
# 9       16.84175      18.93925     2.09750     20.5    15.268625
# 10      16.73250      18.46225     1.72975     19.8    15.435188
# 11      15.98075      17.90300     1.92225     19.3    14.539063
# 12       0.25400       0.39600     0.14200      0.5     0.147500
# 13       0.26825       0.41000     0.14175      0.5     0.161938
# 14       0.25250       0.44000     0.18750      0.6     0.111875
# 15      17.06900      18.41900     1.35000     19.4    16.056500
# 16      16.41275      17.42250     1.00975     18.2    15.655437
# 17      14.66625      16.35000     1.68375     17.6    13.403437
# 18       1.14900       1.49075     0.34175      1.7     0.892688
# 19       1.09125       1.42200     0.33075      1.7     0.843187
# 20       0.88500       1.37200     0.48700      1.7     0.519750
# 21       4.04525       5.03100     0.98575      5.8     3.305937
# 22       3.87925       4.79525     0.91600      5.5     3.192250
# 23       3.25250       4.37850     1.12600      5.2     2.408000
# 24       0.00000       0.00000     0.00000      0.0     0.000000
# 25       0.15150       0.23125     0.07975      0.3     0.091687
# 26       0.57850       0.89625     0.31775      1.1     0.340188
# 27    3158.25000    3441.50000   283.25000   3653.9  2945.812500
# 28    4676.50000    5158.25000   481.75000   5519.6  4315.187500
# 29    1491.25000    1702.25000   211.00000   1860.5  1333.000000
# 30       0.66325       1.23900     0.57575      1.7     0.231438
# 31       0.67050       1.23150     0.56100      1.7     0.249750
# 32       0.63350       1.27875     0.64525      1.8     0.149562
# 33       0.00000       0.00000     0.00000      0.0     0.000000
# 34       1.16150       1.75525     0.59375      2.2     0.716187
# 35       4.58850       6.99550     2.40700      8.8     2.783250
# 36       0.00000       0.00000     0.00000      0.0     0.000000
# 37       0.04125       0.07875     0.03750      0.1     0.013125
# 38       0.14725       0.30900     0.16175      0.4     0.025937
# 39    4866.50000    5387.25000   520.75000   5777.8  4475.937500
# 40    6552.75000    7198.50000   645.75000   7682.8  6068.437500
# 41    1691.75000    1830.00000   138.25000   1933.7  1588.062500
# 42      30.85675      32.53375     1.67700     33.8    29.599000
# 43      30.47150      31.96775     1.49625     33.1    29.349313
# 44      28.75525      30.71800     1.96275     32.2    27.283188
# 45      44.42600      46.62225     2.19625     48.3    42.778813
# 46      41.92725      43.97175     2.04450     45.5    40.393875
# 47      34.00850      36.63400     2.62550     38.6    32.039375
# 48     641.00000     758.75000   117.75000    847.1   552.687500
# 49     871.25000    1009.50000   138.25000   1113.2   767.562500
# 50     233.00000     269.75000    36.75000    297.3   205.437500
# 51       0.00000       0.00000     0.00000      0.0     0.000000
# 52    5738.97075    8561.36325  2822.39250  10678.2  3622.176375
# 53    1396.66650    2061.36400   664.69750   2559.9   898.143375
# 54       0.00000       0.00000     0.00000      0.0     0.000000
# 55       0.00000       0.11875     0.11875      0.2    -0.089062
# 56       0.00000       0.45875     0.45875      0.8    -0.344062
# 57       0.00000       0.00000     0.00000      0.0     0.000000
# 58       1.24250       2.23275     0.99025      3.0     0.499812
# 59       4.91275       8.62550     3.71275     11.4     2.128187
# 60       0.00000       0.00000     0.00000      0.0     0.000000
# 61   12640.00000           NaN         NaN      NaN          NaN
# 62       0.00000    2625.00000  2625.00000   4593.8 -1968.750000
# 63       0.00000       0.00000     0.00000      0.0     0.000000
# 64       0.00000       0.10675     0.10675      0.2    -0.080062
# 65       0.00000       0.41100     0.41100      0.7    -0.308250
# 66      32.32950      36.21875     3.88925     39.1    29.412562
# 67      31.78850      34.73625     2.94775     36.9    29.577687
# 68      29.46425      32.91925     3.45500     35.5    26.873000
# 69      38.77250      42.21675     3.44425     44.8    36.189312
# 70      34.69050      38.01875     3.32825     40.5    32.194313
# 71      22.00400      26.95100     4.94700     30.7    18.293750
# 72      91.43000      93.28625     1.85625     94.7    90.037813
# 73      91.75800      93.37250     1.61450     94.6    90.547125
# 74      91.73600      94.36700     2.63100     96.3    89.762750
# 75      93.12825      97.31425     4.18600    100.5    89.988750
# 76      86.28750      92.55950     6.27200     97.3    81.583500
# 77      70.90625      85.12425    14.21800     95.8    60.242750
# 78      21.18200      22.79050     1.60850     24.0    19.975625
# 79      19.77975      21.20100     1.42125     22.3    18.713812
# 80      15.85600      17.95275     2.09675     19.5    14.283438
# 81      18.51700      20.92775     2.41075     22.7    16.708938
# 82      16.77900      18.96725     2.18825     20.6    15.137812
# 83      12.41725      14.57525     2.15800     16.2    10.798750
# 84       1.13550       1.55525     0.41975      1.9     0.820687
# 85       1.13000       1.48900     0.35900      1.8     0.860750
# 86       0.98400       1.41400     0.43000      1.7     0.661500
# 87      13.68575      15.26575     1.58000     16.5    12.500750
# 88      13.81475      15.23325     1.41850     16.3    12.750875
# 89      13.38700      15.79900     2.41200     17.6    11.578000
# 90      53.17725      55.74850     2.57125     57.7    51.248812
# 91      52.98250      55.55550     2.57300     57.5    51.052750
# 92      52.03175      56.27375     4.24200     59.5    48.850250
# 93      59.58075      61.73500     2.15425     63.4    57.965062
# 94      58.02550      60.20375     2.17825     61.8    56.391813
# 95      54.51900      57.45350     2.93450     59.7    52.318125
# 96      91.08550      93.58100     2.49550     95.5    89.213875
# 97      91.21425      93.58650     2.37225     95.4    89.435062
# 98      91.44775      93.35850     1.91075     94.8    90.014687
# 99       2.47725       3.05225     0.57500      3.5     2.046000

# %%
upper_lower_df.shape
# Out:
# (102, 106)

# %%
def calculate_upper_lower(df, parent_column='parent_id'):
    # Ensure parent_column is present in the dataframe
    if parent_column not in df.columns:
        raise ValueError(f"{parent_column} not found in the dataframe")
    
    # Define the function to apply to each row
    def calculate_row(row):
        if pd.isna(row[parent_column]) or row[parent_column] == '':
            # Apply 1.25 logic for rows where parent_id is null, empty, or None
            upper = row['3rd Quartile'] + (1.25 * row['IQR'])
            lower = row['1st Quartile'] - (1.25 * row['IQR'])
        else:
            # Apply 0.75 logic for other rows
            upper = row['3rd Quartile'] + (0.75 * row['IQR'])
            lower = row['1st Quartile'] - (0.75 * row['IQR'])
        
        return pd.Series({'Upper': upper, 'Lower': lower})
    
    # Apply the function row by row
    df[['Upper', 'Lower']] = df.apply(calculate_row, axis=1)

    # Round the Upper column to 1 decimal place
    #df['Upper'] = df['Upper'].round(1)

    return df

# %%
upper_lower_df = calculate_upper_lower(quartiles_iqr_df)
#upper_lower_df =upper_lower_df[['display_names','operating_system_type','1st Quartile','3rd Quartile', 'IQR', 'Upper', 'Lower']]
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 200)      # Show 100 rows
upper_lower_df.head()
# Out:
#     create_dt metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 0  2025-01-28       186          15               5                186.0
# 1  2025-01-28  10000020          15             NaN                  NaN
# 2  2025-01-28       420          15               5                184.0
# 3  2025-01-28       187          15               5                187.0
# 4  2025-01-28  10000021          15             NaN                  NaN
#
#    metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 0           4.0       4.0      185.0                SH   SMART HELP
# 1           NaN       NaN      185.0                SH   SMART HELP
# 2          22.0       4.0      419.0                SH   SMART HELP
# 3           5.0       4.0      185.0                SH   SMART HELP
# 4           NaN       NaN      185.0                SH   SMART HELP
#
#                               metrics                     display_names  \
# 0       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 1       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 2       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 3  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
# 4  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
#
#   operating_system_type metric_nature 29-08-2024 30-08-2024 31-08-2024  \
# 0             Apple iOS      Negative     78.947       84.0     80.909
# 1                  Both           NaN     78.689     80.556     80.392
# 2        Google Android      Negative     78.261     72.727      79.07
# 3             Apple iOS      Negative     14.474       10.0     11.818
# 4                  Both           NaN     13.115     11.111     13.725
#
#   01-09-2024 02-09-2024 03-09-2024 04-09-2024 05-09-2024 06-09-2024  \
# 0     68.235     78.049     74.118     73.786     77.622     81.053
# 1     68.462     76.923      70.29     74.497     76.682     79.221
# 2     68.889     74.286     64.151     76.087       75.0     76.271
# 3     18.824     15.854     15.294     16.505     11.888     10.526
# 4     18.462     17.094     21.739     16.779     13.901     11.688
#
#   07-09-2024 08-09-2024 09-09-2024 10-09-2024 11-09-2024 12-09-2024  \
# 0     77.228     75.455     83.784     88.095     72.727     85.321
# 1     71.014     74.405     75.214     83.871     76.271     84.516
# 2     54.054     72.414     60.465       75.0     82.927     82.609
# 3     12.871     16.364      8.108      7.143     19.481     11.009
# 4     16.667     19.048      14.53     12.903     14.407     12.258
#
#   13-09-2024 14-09-2024 15-09-2024 16-09-2024 17-09-2024 18-09-2024  \
# 0     82.653     80.435     89.046     60.099      8.108      8.333
# 1     83.099     77.419     90.612     60.912       11.0     10.345
# 2     84.091      68.75     92.754       62.5     19.231     14.815
# 3     14.286      9.783      9.541     21.182      1.351        0.0
# 4     11.972     12.903      7.755     23.127        1.0        0.0
#
#   19-09-2024 20-09-2024 21-09-2024 22-09-2024 23-09-2024 24-09-2024  \
# 0      7.955      6.667      4.615      7.595     10.938     16.667
# 1      7.965      6.542      7.407       8.13      9.195     16.176
# 2        8.0       6.25     11.628      9.091      4.348     14.706
# 3      2.273      1.333        0.0        0.0        0.0        0.0
# 4       1.77      0.935        0.0        0.0      1.149        0.0
#
#   25-09-2024 26-09-2024 27-09-2024 28-09-2024 29-09-2024 30-09-2024  \
# 0      9.091     11.628     11.765     10.145      7.921     10.753
# 1      9.804      11.29     14.286     11.828      8.955       12.5
# 2     11.111     10.526     18.919     16.667     12.121     18.519
# 3      1.515      1.163        0.0        0.0        0.0        0.0
# 4       0.98      0.806        0.0        0.0        0.0        0.0
#
#   01-10-2024 02-10-2024 03-10-2024 04-10-2024 05-10-2024 06-10-2024  \
# 0      8.974     10.667     63.636     75.862     75.789     73.958
# 1       8.85      8.612     65.254     77.344     69.014     73.485
# 2      8.571       3.39     68.293     80.488     55.319     72.222
# 3        0.0        0.0      10.39      9.195      9.474     16.667
# 4        0.0        0.0      8.475     10.156     15.493     18.182
#
#   07-10-2024 08-10-2024 09-10-2024 10-10-2024 11-10-2024 12-10-2024  \
# 0     75.309     69.663     68.085     74.667     75.714     78.824
# 1       75.0     66.942     65.854     72.727     70.707     74.167
# 2     74.074     59.375     58.621     66.667     58.621     62.857
# 3     18.519      15.73      13.83     13.333     11.429     11.765
# 4     18.519     16.529      16.26     15.152     15.152       17.5
#
#   13-10-2024 14-10-2024 15-10-2024 16-10-2024 17-10-2024 18-10-2024  \
# 0     60.317     66.667     63.725     57.955     57.647     58.889
# 1     61.053     66.154     65.909     57.895     58.586     62.295
# 2       62.5     64.706     73.333     57.692     64.286     71.875
# 3     22.222     17.708     22.549     28.409     22.353     22.222
# 4     22.105     15.385     22.727     26.316     25.253     21.311
#
#   19-10-2024 20-10-2024 21-10-2024 22-10-2024 23-10-2024 24-10-2024  \
# 0     54.455     62.195     47.561     61.765     58.095     63.014
# 1     55.072     61.947     55.085     66.412     58.451     64.356
# 2     56.757      61.29     72.222     82.759     59.459     67.857
# 3     37.624     23.171     26.829     26.471     27.619     26.027
# 4     34.058     24.779     21.186     25.191     26.761     27.723
#
#   25-10-2024 26-10-2024 27-10-2024 28-10-2024 29-10-2024 30-10-2024  \
# 0     54.545     59.211      56.79     65.116      51.25     55.102
# 1     54.762     57.983     58.182     64.516     49.495     57.246
# 2     55.263     55.814     62.069     63.158     42.105       62.5
# 3     26.136     22.368     24.691      29.07       25.0     22.449
# 4     30.159      24.37     24.545     27.419     27.273     22.464
#
#   31-10-2024 01-11-2024 02-11-2024 03-11-2024 04-11-2024 05-11-2024  \
# 0     54.545     71.429     67.442     65.854     63.095     54.412
# 1      56.25     71.329     66.387     67.816       64.8     59.574
# 2       60.0     71.053     63.636     72.549     68.293     73.077
# 3     25.974     17.143     24.419     20.325     27.381     27.941
# 4     23.214      19.58      24.37     21.264       22.4     23.404
#
#   06-11-2024 07-11-2024 08-11-2024 09-11-2024 10-11-2024 11-11-2024  \
# 0     66.667       60.0     53.846     57.895     46.479     53.086
# 1     68.687     54.701     55.455     57.522     47.423     55.446
# 2     73.333     40.625     59.375     56.757       50.0       65.0
# 3     21.739     23.529     17.949       25.0     33.803     28.395
# 4     19.192     24.786       20.0     25.664     34.021     27.723
#
#   12-11-2024 13-11-2024 14-11-2024 15-11-2024 16-11-2024 17-11-2024  \
# 0     65.556     56.164     63.529       70.0       60.0     54.545
# 1     67.391     57.009     61.789     65.254     57.895     53.153
# 2     70.833     58.824     57.895     55.263     53.488       50.0
# 3       20.0     27.397     17.647       20.0     23.333     23.377
# 4     18.841     24.299     17.886     18.644     21.805     27.928
#
#   18-11-2024 19-11-2024 20-11-2024 21-11-2024 22-11-2024 23-11-2024  \
# 0     55.357     51.351     59.459       55.0     56.962     56.818
# 1     52.941     49.541     55.446     56.911     57.895     48.701
# 2     48.276     45.714     44.444     60.465       60.0     37.879
# 3     26.786     22.973     25.676       17.5     20.253     22.727
# 4     29.412     26.606     26.733     21.951     21.053     25.974
#
#   24-11-2024 25-11-2024 26-11-2024  1st Quartile  3rd Quartile       IQR  \
# 0     62.295     66.142     66.216      54.42275      73.52125  19.09850
# 1     65.318     61.053     64.151      54.71625      70.60275  15.88650
# 2     72.549     50.794     59.375      50.00000      72.13525  22.13525
# 3     14.754     16.535     21.622      10.09750      23.29250  13.19500
# 4     13.295     18.947     23.585      12.41925      24.12050  11.70125
#
#        Upper      Lower
# 0  87.845125  40.098875
# 1  82.517625  42.801375
# 2  88.736688  33.398562
# 3  33.188750   0.201250
# 4  32.896437   3.643313

# %%
upper_lower_df.shape
# Out:
# (102, 109)

# %%
import numpy as np
import pandas as pd

def calculate_last7_and_30_days(df):
    # Extract the date columns (skip the non-date columns like 'display_names' and 'operating_system_type')
    datecolumn = [col for col in df.columns if '-' in col]
    
    # Exclude the latest date column (the first one)
    last_7_columns = datecolumn[-8:-1]  # Get the last 7 columns excluding the latest date
    last_30_columns = datecolumn[-31:-1]

    # Extract the date part and convert them to datetime objects
    date_objects = [pd.to_datetime(col.split()[0], format='%d-%m-%Y') for col in datecolumn]

    # Get the column corresponding to the latest date
    latest_date = max(date_objects)
    latest_date_column = datecolumn[date_objects.index(latest_date)]

    # Create a new column 'Yesterday' with the values from the latest date column
    df.loc[:, 'Yesterday'] = df[latest_date_column]
    
    # Ensure numeric columns before performing mean calculation
    df[last_7_columns] = df[last_7_columns].apply(pd.to_numeric, errors='coerce')
    df[last_30_columns] = df[last_30_columns].apply(pd.to_numeric, errors='coerce')

    # Calculate the mean for each row across the last 7 and 30 date columns
    df.loc[:, 'last_7_days'] = df[last_7_columns].mean(axis=1)
    df.loc[:, 'last_30_days'] = df[last_30_columns].mean(axis=1)

    # Replace 0 and NaN values in 'last_7_days' and 'last_30_days' with NaN to avoid division by zero
    df['last_7_days'] = df['last_7_days'].replace(0, np.nan)
    df['last_30_days'] = df['last_30_days'].replace(0, np.nan)

    # Calculate the percentage change for 'Last 7 Days' with a check for NaN
    df.loc[:, '% Change Last 7 Days'] = np.where(
        df['last_7_days'].isna(), 0, 
        (df['Yesterday'] - df['last_7_days']) / df['last_7_days'] * 100
    )

    # Calculate the percentage change for 'Last 30 Days' with a check for NaN
    df.loc[:, '% Change Last 30 Days'] = np.where(
        df['last_30_days'].isna(), 0, 
        (df['Yesterday'] - df['last_30_days']) / df['last_30_days'] * 100
    )

    # Round the percentage changes to 1 decimal place
    df.loc[:, '% Change Last 7 Days'] = df['% Change Last 7 Days'].round(1)
    df.loc[:, '% Change Last 30 Days'] = df['% Change Last 30 Days'].round(1)
    
    return df

# %%
last_7_and_30_days_df  = calculate_last7_and_30_days(upper_lower_df)
#last_7_and_30_days_df = last_7_and_30_days_df[['metric_id', 'metrics', 'display_names', 'operating_system_type', 'feature_name', 'parent_id','Yesterday', 'last_7_days', 'last_30_days', '% Change Last 7 Days', '% Change Last 30 Days']]
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 100)
last_7_and_30_days_df.head()
# Out:
#     create_dt metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 0  2025-01-28       186          15               5                186.0
# 1  2025-01-28  10000020          15             NaN                  NaN
# 2  2025-01-28       420          15               5                184.0
# 3  2025-01-28       187          15               5                187.0
# 4  2025-01-28  10000021          15             NaN                  NaN
#
#    metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 0           4.0       4.0      185.0                SH   SMART HELP
# 1           NaN       NaN      185.0                SH   SMART HELP
# 2          22.0       4.0      419.0                SH   SMART HELP
# 3           5.0       4.0      185.0                SH   SMART HELP
# 4           NaN       NaN      185.0                SH   SMART HELP
#
#                               metrics                     display_names  \
# 0       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 1       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 2       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 3  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
# 4  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
#
#   operating_system_type metric_nature 29-08-2024 30-08-2024 31-08-2024  \
# 0             Apple iOS      Negative     78.947       84.0     80.909
# 1                  Both           NaN     78.689     80.556     80.392
# 2        Google Android      Negative     78.261     72.727      79.07
# 3             Apple iOS      Negative     14.474       10.0     11.818
# 4                  Both           NaN     13.115     11.111     13.725
#
#   01-09-2024 02-09-2024 03-09-2024 04-09-2024 05-09-2024 06-09-2024  \
# 0     68.235     78.049     74.118     73.786     77.622     81.053
# 1     68.462     76.923      70.29     74.497     76.682     79.221
# 2     68.889     74.286     64.151     76.087       75.0     76.271
# 3     18.824     15.854     15.294     16.505     11.888     10.526
# 4     18.462     17.094     21.739     16.779     13.901     11.688
#
#   07-09-2024 08-09-2024 09-09-2024 10-09-2024 11-09-2024 12-09-2024  \
# 0     77.228     75.455     83.784     88.095     72.727     85.321
# 1     71.014     74.405     75.214     83.871     76.271     84.516
# 2     54.054     72.414     60.465       75.0     82.927     82.609
# 3     12.871     16.364      8.108      7.143     19.481     11.009
# 4     16.667     19.048      14.53     12.903     14.407     12.258
#
#   13-09-2024 14-09-2024 15-09-2024 16-09-2024 17-09-2024 18-09-2024  \
# 0     82.653     80.435     89.046     60.099      8.108      8.333
# 1     83.099     77.419     90.612     60.912       11.0     10.345
# 2     84.091      68.75     92.754       62.5     19.231     14.815
# 3     14.286      9.783      9.541     21.182      1.351        0.0
# 4     11.972     12.903      7.755     23.127        1.0        0.0
#
#   19-09-2024 20-09-2024 21-09-2024 22-09-2024 23-09-2024 24-09-2024  \
# 0      7.955      6.667      4.615      7.595     10.938     16.667
# 1      7.965      6.542      7.407       8.13      9.195     16.176
# 2        8.0       6.25     11.628      9.091      4.348     14.706
# 3      2.273      1.333        0.0        0.0        0.0        0.0
# 4       1.77      0.935        0.0        0.0      1.149        0.0
#
#   25-09-2024 26-09-2024 27-09-2024 28-09-2024 29-09-2024 30-09-2024  \
# 0      9.091     11.628     11.765     10.145      7.921     10.753
# 1      9.804      11.29     14.286     11.828      8.955       12.5
# 2     11.111     10.526     18.919     16.667     12.121     18.519
# 3      1.515      1.163        0.0        0.0        0.0        0.0
# 4       0.98      0.806        0.0        0.0        0.0        0.0
#
#   01-10-2024 02-10-2024 03-10-2024 04-10-2024 05-10-2024 06-10-2024  \
# 0      8.974     10.667     63.636     75.862     75.789     73.958
# 1       8.85      8.612     65.254     77.344     69.014     73.485
# 2      8.571       3.39     68.293     80.488     55.319     72.222
# 3        0.0        0.0      10.39      9.195      9.474     16.667
# 4        0.0        0.0      8.475     10.156     15.493     18.182
#
#   07-10-2024 08-10-2024 09-10-2024 10-10-2024 11-10-2024 12-10-2024  \
# 0     75.309     69.663     68.085     74.667     75.714     78.824
# 1       75.0     66.942     65.854     72.727     70.707     74.167
# 2     74.074     59.375     58.621     66.667     58.621     62.857
# 3     18.519      15.73      13.83     13.333     11.429     11.765
# 4     18.519     16.529      16.26     15.152     15.152       17.5
#
#   13-10-2024 14-10-2024 15-10-2024 16-10-2024 17-10-2024 18-10-2024  \
# 0     60.317     66.667     63.725     57.955     57.647     58.889
# 1     61.053     66.154     65.909     57.895     58.586     62.295
# 2       62.5     64.706     73.333     57.692     64.286     71.875
# 3     22.222     17.708     22.549     28.409     22.353     22.222
# 4     22.105     15.385     22.727     26.316     25.253     21.311
#
#   19-10-2024 20-10-2024 21-10-2024 22-10-2024 23-10-2024 24-10-2024  \
# 0     54.455     62.195     47.561     61.765     58.095     63.014
# 1     55.072     61.947     55.085     66.412     58.451     64.356
# 2     56.757      61.29     72.222     82.759     59.459     67.857
# 3     37.624     23.171     26.829     26.471     27.619     26.027
# 4     34.058     24.779     21.186     25.191     26.761     27.723
#
#   25-10-2024 26-10-2024  27-10-2024  28-10-2024  29-10-2024  30-10-2024  \
# 0     54.545     59.211      56.790      65.116      51.250      55.102
# 1     54.762     57.983      58.182      64.516      49.495      57.246
# 2     55.263     55.814      62.069      63.158      42.105      62.500
# 3     26.136     22.368      24.691      29.070      25.000      22.449
# 4     30.159      24.37      24.545      27.419      27.273      22.464
#
#    31-10-2024  01-11-2024  02-11-2024  03-11-2024  04-11-2024  05-11-2024  \
# 0      54.545      71.429      67.442      65.854      63.095      54.412
# 1      56.250      71.329      66.387      67.816      64.800      59.574
# 2      60.000      71.053      63.636      72.549      68.293      73.077
# 3      25.974      17.143      24.419      20.325      27.381      27.941
# 4      23.214      19.580      24.370      21.264      22.400      23.404
#
#    06-11-2024  07-11-2024  08-11-2024  09-11-2024  10-11-2024  11-11-2024  \
# 0      66.667      60.000      53.846      57.895      46.479      53.086
# 1      68.687      54.701      55.455      57.522      47.423      55.446
# 2      73.333      40.625      59.375      56.757      50.000      65.000
# 3      21.739      23.529      17.949      25.000      33.803      28.395
# 4      19.192      24.786      20.000      25.664      34.021      27.723
#
#    12-11-2024  13-11-2024  14-11-2024  15-11-2024  16-11-2024  17-11-2024  \
# 0      65.556      56.164      63.529      70.000      60.000      54.545
# 1      67.391      57.009      61.789      65.254      57.895      53.153
# 2      70.833      58.824      57.895      55.263      53.488      50.000
# 3      20.000      27.397      17.647      20.000      23.333      23.377
# 4      18.841      24.299      17.886      18.644      21.805      27.928
#
#    18-11-2024  19-11-2024  20-11-2024  21-11-2024  22-11-2024  23-11-2024  \
# 0      55.357      51.351      59.459      55.000      56.962      56.818
# 1      52.941      49.541      55.446      56.911      57.895      48.701
# 2      48.276      45.714      44.444      60.465      60.000      37.879
# 3      26.786      22.973      25.676      17.500      20.253      22.727
# 4      29.412      26.606      26.733      21.951      21.053      25.974
#
#    24-11-2024  25-11-2024 26-11-2024  1st Quartile  3rd Quartile       IQR  \
# 0      62.295      66.142     66.216      54.42275      73.52125  19.09850
# 1      65.318      61.053     64.151      54.71625      70.60275  15.88650
# 2      72.549      50.794     59.375      50.00000      72.13525  22.13525
# 3      14.754      16.535     21.622      10.09750      23.29250  13.19500
# 4      13.295      18.947     23.585      12.41925      24.12050  11.70125
#
#        Upper      Lower Yesterday  last_7_days  last_30_days  \
# 0  87.845125  40.098875    66.216    58.289571     59.206200
# 1  82.517625  42.801375    64.151    56.409286     58.837533
# 2  88.736688  33.398562    59.375    53.120714     58.331800
# 3  33.188750   0.201250    21.622    20.059714     23.125533
# 4  32.896437   3.643313    23.585    22.079857     23.356433
#
#   % Change Last 7 Days % Change Last 30 Days
# 0            13.598365             11.839638
# 1            13.724184              9.030743
# 2            11.773723               1.78839
# 3             7.788175             -6.501616
# 4             6.816814              0.978603

# %%
last_7_and_30_days_df.shape
# Out:
# (102, 114)

# %%
last_7_and_30_days_df[['1st Quartile', '3rd Quartile', 'IQR','Upper', 'Lower', 'Yesterday', 'last_7_days', 'last_30_days', '% Change Last 7 Days', '% Change Last 30 Days']] = last_7_and_30_days_df[['1st Quartile', '3rd Quartile', 'IQR','Upper', 'Lower', 'Yesterday', 'last_7_days', 'last_30_days', '% Change Last 7 Days', '% Change Last 30 Days']].round(3)

# %%
last_7_and_30_days_df.head()
# Out:
#     create_dt metric_id  feature_id feature_seq_num  metric_sequence_num  \
# 0  2025-01-28       186          15               5                186.0
# 1  2025-01-28  10000020          15             NaN                  NaN
# 2  2025-01-28       420          15               5                184.0
# 3  2025-01-28       187          15               5                187.0
# 4  2025-01-28  10000021          15             NaN                  NaN
#
#    metric_seqno  level_no  parent_id unique_identifier feature_name  \
# 0           4.0       4.0      185.0                SH   SMART HELP
# 1           NaN       NaN      185.0                SH   SMART HELP
# 2          22.0       4.0      419.0                SH   SMART HELP
# 3           5.0       4.0      185.0                SH   SMART HELP
# 4           NaN       NaN      185.0                SH   SMART HELP
#
#                               metrics                     display_names  \
# 0       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 1       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 2       DR_SmartHelp Result - Unknown       1st common reason (Unknown)
# 3  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
# 4  DR_SmartHelp Result - Disconnected  2nd common reason (Disconnected)
#
#   operating_system_type metric_nature 29-08-2024 30-08-2024 31-08-2024  \
# 0             Apple iOS      Negative     78.947       84.0     80.909
# 1                  Both           NaN     78.689     80.556     80.392
# 2        Google Android      Negative     78.261     72.727      79.07
# 3             Apple iOS      Negative     14.474       10.0     11.818
# 4                  Both           NaN     13.115     11.111     13.725
#
#   01-09-2024 02-09-2024 03-09-2024 04-09-2024 05-09-2024 06-09-2024  \
# 0     68.235     78.049     74.118     73.786     77.622     81.053
# 1     68.462     76.923      70.29     74.497     76.682     79.221
# 2     68.889     74.286     64.151     76.087       75.0     76.271
# 3     18.824     15.854     15.294     16.505     11.888     10.526
# 4     18.462     17.094     21.739     16.779     13.901     11.688
#
#   07-09-2024 08-09-2024 09-09-2024 10-09-2024 11-09-2024 12-09-2024  \
# 0     77.228     75.455     83.784     88.095     72.727     85.321
# 1     71.014     74.405     75.214     83.871     76.271     84.516
# 2     54.054     72.414     60.465       75.0     82.927     82.609
# 3     12.871     16.364      8.108      7.143     19.481     11.009
# 4     16.667     19.048      14.53     12.903     14.407     12.258
#
#   13-09-2024 14-09-2024 15-09-2024 16-09-2024 17-09-2024 18-09-2024  \
# 0     82.653     80.435     89.046     60.099      8.108      8.333
# 1     83.099     77.419     90.612     60.912       11.0     10.345
# 2     84.091      68.75     92.754       62.5     19.231     14.815
# 3     14.286      9.783      9.541     21.182      1.351        0.0
# 4     11.972     12.903      7.755     23.127        1.0        0.0
#
#   19-09-2024 20-09-2024 21-09-2024 22-09-2024 23-09-2024 24-09-2024  \
# 0      7.955      6.667      4.615      7.595     10.938     16.667
# 1      7.965      6.542      7.407       8.13      9.195     16.176
# 2        8.0       6.25     11.628      9.091      4.348     14.706
# 3      2.273      1.333        0.0        0.0        0.0        0.0
# 4       1.77      0.935        0.0        0.0      1.149        0.0
#
#   25-09-2024 26-09-2024 27-09-2024 28-09-2024 29-09-2024 30-09-2024  \
# 0      9.091     11.628     11.765     10.145      7.921     10.753
# 1      9.804      11.29     14.286     11.828      8.955       12.5
# 2     11.111     10.526     18.919     16.667     12.121     18.519
# 3      1.515      1.163        0.0        0.0        0.0        0.0
# 4       0.98      0.806        0.0        0.0        0.0        0.0
#
#   01-10-2024 02-10-2024 03-10-2024 04-10-2024 05-10-2024 06-10-2024  \
# 0      8.974     10.667     63.636     75.862     75.789     73.958
# 1       8.85      8.612     65.254     77.344     69.014     73.485
# 2      8.571       3.39     68.293     80.488     55.319     72.222
# 3        0.0        0.0      10.39      9.195      9.474     16.667
# 4        0.0        0.0      8.475     10.156     15.493     18.182
#
#   07-10-2024 08-10-2024 09-10-2024 10-10-2024 11-10-2024 12-10-2024  \
# 0     75.309     69.663     68.085     74.667     75.714     78.824
# 1       75.0     66.942     65.854     72.727     70.707     74.167
# 2     74.074     59.375     58.621     66.667     58.621     62.857
# 3     18.519      15.73      13.83     13.333     11.429     11.765
# 4     18.519     16.529      16.26     15.152     15.152       17.5
#
#   13-10-2024 14-10-2024 15-10-2024 16-10-2024 17-10-2024 18-10-2024  \
# 0     60.317     66.667     63.725     57.955     57.647     58.889
# 1     61.053     66.154     65.909     57.895     58.586     62.295
# 2       62.5     64.706     73.333     57.692     64.286     71.875
# 3     22.222     17.708     22.549     28.409     22.353     22.222
# 4     22.105     15.385     22.727     26.316     25.253     21.311
#
#   19-10-2024 20-10-2024 21-10-2024 22-10-2024 23-10-2024 24-10-2024  \
# 0     54.455     62.195     47.561     61.765     58.095     63.014
# 1     55.072     61.947     55.085     66.412     58.451     64.356
# 2     56.757      61.29     72.222     82.759     59.459     67.857
# 3     37.624     23.171     26.829     26.471     27.619     26.027
# 4     34.058     24.779     21.186     25.191     26.761     27.723
#
#   25-10-2024 26-10-2024  27-10-2024  28-10-2024  29-10-2024  30-10-2024  \
# 0     54.545     59.211      56.790      65.116      51.250      55.102
# 1     54.762     57.983      58.182      64.516      49.495      57.246
# 2     55.263     55.814      62.069      63.158      42.105      62.500
# 3     26.136     22.368      24.691      29.070      25.000      22.449
# 4     30.159      24.37      24.545      27.419      27.273      22.464
#
#    31-10-2024  01-11-2024  02-11-2024  03-11-2024  04-11-2024  05-11-2024  \
# 0      54.545      71.429      67.442      65.854      63.095      54.412
# 1      56.250      71.329      66.387      67.816      64.800      59.574
# 2      60.000      71.053      63.636      72.549      68.293      73.077
# 3      25.974      17.143      24.419      20.325      27.381      27.941
# 4      23.214      19.580      24.370      21.264      22.400      23.404
#
#    06-11-2024  07-11-2024  08-11-2024  09-11-2024  10-11-2024  11-11-2024  \
# 0      66.667      60.000      53.846      57.895      46.479      53.086
# 1      68.687      54.701      55.455      57.522      47.423      55.446
# 2      73.333      40.625      59.375      56.757      50.000      65.000
# 3      21.739      23.529      17.949      25.000      33.803      28.395
# 4      19.192      24.786      20.000      25.664      34.021      27.723
#
#    12-11-2024  13-11-2024  14-11-2024  15-11-2024  16-11-2024  17-11-2024  \
# 0      65.556      56.164      63.529      70.000      60.000      54.545
# 1      67.391      57.009      61.789      65.254      57.895      53.153
# 2      70.833      58.824      57.895      55.263      53.488      50.000
# 3      20.000      27.397      17.647      20.000      23.333      23.377
# 4      18.841      24.299      17.886      18.644      21.805      27.928
#
#    18-11-2024  19-11-2024  20-11-2024  21-11-2024  22-11-2024  23-11-2024  \
# 0      55.357      51.351      59.459      55.000      56.962      56.818
# 1      52.941      49.541      55.446      56.911      57.895      48.701
# 2      48.276      45.714      44.444      60.465      60.000      37.879
# 3      26.786      22.973      25.676      17.500      20.253      22.727
# 4      29.412      26.606      26.733      21.951      21.053      25.974
#
#    24-11-2024  25-11-2024 26-11-2024  1st Quartile  3rd Quartile     IQR  \
# 0      62.295      66.142     66.216        54.423        73.521  19.099
# 1      65.318      61.053     64.151        54.716        70.603  15.886
# 2      72.549      50.794     59.375        50.000        72.135  22.135
# 3      14.754      16.535     21.622        10.098        23.292  13.195
# 4      13.295      18.947     23.585        12.419        24.120  11.701
#
#     Upper   Lower Yesterday  last_7_days  last_30_days % Change Last 7 Days  \
# 0  87.845  40.099    66.216       58.290        59.206            13.598365
# 1  82.518  42.801    64.151       56.409        58.838            13.724184
# 2  88.737  33.399    59.375       53.121        58.332            11.773723
# 3  33.189   0.201    21.622       20.060        23.126             7.788175
# 4  32.896   3.643    23.585       22.080        23.356             6.816814
#
#   % Change Last 30 Days
# 0             11.839638
# 1              9.030743
# 2               1.78839
# 3             -6.501616
# 4              0.978603

# %%
last_7_and_30_days_df.shape
# Out:
# (102, 114)

# %%
#last_7_and_30_days_df.to_csv(r'D:\Healthsore Data\table_4_data_3_featuresnew.csv', index = False)

# %%
fouth_table_columns = ['create_dt','metric_id', 'feature_id', 'unique_identifier', 'feature_name', 'metrics', 'display_names', 'operating_system_type', '1st Quartile', '3rd Quartile', 'IQR', 'Upper', 'Lower', 'Yesterday', 'last_7_days', 'last_30_days', '% Change Last 7 Days', '% Change Last 30 Days']

# %%
fourth_table_melted_df = pd.melt(last_7_and_30_days_df, id_vars=fouth_table_columns, 
                     value_vars=date_columns, 
                     var_name='Date', 
                     value_name='Value')

# %%
fourth_table_melted_df.shape
# Out:
# (9180, 20)

# %%
#fourth_table_melted_df.to_csv(r'D:\Healthsore Data\table_4_data_3_features_athena.csv', index = False)
